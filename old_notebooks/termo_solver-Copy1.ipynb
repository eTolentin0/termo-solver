# %%
#não executar, apenas mandar para o final para adicionar palavras

with open('palavras_termo.txt','w', encoding = 'utf8') as f:
    for palavra in palavras:
        f.write("%s\n" % palavra)
    print('done')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-485eaeabf26b> in <module>
#       1 with open('palavras_termo.txt','w', encoding = 'utf8') as f:
# ----> 2     for palavra in palavras:
#       3         f.write("%s\n" % palavra)
#       4     print('done')
#
# NameError: name 'palavras' is not defined

# %%
import pandas as pd
import numpy as np

# %%
import unicodedata
import re

def remove_acentos(string):
    normalized = unicodedata.normalize('NFD', string)
    return re.sub(r'[\u0300-\u036f]', '', normalized).casefold()

# %%
def conta_vogais(palavra):
    
    contador = 0
    vogais = 'aeiouAEIOU'
    allowed = frozenset('aeiouAEIOU')
    
    for letra in palavra:
        if letra in vogais:
            contador += 1
    vogais_unicas = len(allowed.intersection(palavra))
    
    return vogais_unicas, contador


conta_vogais('perde')
# Out:
# (1, 2)

# %%
palavras = []
file = open('br-utf8.txt', 'r', encoding = 'utf8')

while True:
    line = file.readline()
    palavra = line.strip().replace('\n','')
    if not line:
        break
    if len(palavra) == 5:
        #print(palavra)
        palavras.append(remove_acentos(palavra))
        

file.close()


#nesse caso não tem a palavra lermo, então vamos remover da lista e rodar novamente
#criar uma função para quando isso acontecer e criar uma lista das palavras que o termo não aceita!
#assim podemos ir melhorando o algoritmo

palavras.remove('lermo')
palavras.remove('canaa')
#print(len(palavras))
df = pd.DataFrame(palavras)
df.drop_duplicates(inplace = True)
df.rename(columns = {0:'palavra'}, inplace = True)

df['n_vogais'] = df['palavra'].apply(lambda x: conta_vogais(x)[1])
df['vogais_unicas'] = df['palavra'].apply(lambda x: conta_vogais(x)[0])


df['letra_0'] = df.palavra.str[0]
df['letra_1'] = df.palavra.str[1]
df['letra_2'] = df.palavra.str[2]
df['letra_3'] = df.palavra.str[3]
df['letra_4'] = df.palavra.str[4]

df.head()
# Out:
#   palavra  n_vogais  vogais_unicas letra_0 letra_1 letra_2 letra_3 letra_4
# 0   aarao         4              2       a       a       r       a       o
# 1   abner         2              2       a       b       n       e       r
# 2   acaia         4              2       a       c       a       i       a
# 3   acker         2              2       a       c       k       e       r
# 4   aires         3              3       a       i       r       e       s

# %%
df.to_csv('br-utf8.csv', index = False)

# %%
palavras = []
file = open('br-utf8.txt', 'r', encoding = 'utf8')

while True:
    line = file.readline()
    palavra = line.strip().replace('\n','')
    if not line:
        break
    if len(palavra) == 5:
        #print(palavra)
        palavras.append(remove_acentos(palavra))
        

file.close()

# %%
#nesse caso não tem a palavra lermo, então vamos remover da lista e rodar novamente
#criar uma função para quando isso acontecer e criar uma lista das palavras que o termo não aceita!
#assim podemos ir melhorando o algoritmo

palavras.remove('lermo')
palavras.remove('canaa')
print(len(palavras))
palavras
# Out:
# 6024
# ['aarao',
#  'abner',
#  'acaia',
#  'acker',
#  'aires',
#  'alair',
#  'alceu',
#  'algol',
#  'aline',
#  'alpes',
#  'amapa',
#  'andre',
#  'argel',
#  'argos',
#  'artur',
#  'aecio',
#  'babel',
#  'bagda',
#  'bangu',
#  'belem',
#  'bento',
#  'berna',
#  'berta',
#  'bielo',
#  'borba',
#  'bruno',
#  'carla',
#  'ceara',
#  'chica',
#  'chico',
#  'chile',
#  'china',
#  'couto',
#  'catia',
#  'cesar',
#  'dafne',
#  'darci',
#  'dario',
#  'david',
#  'denis',
#  'diana',
#  'dacia',
#  'edgar',
#  'edite',
#  'egito',
#  'elias',
#  'elisa',
#  'elixa',
#  'emaus',
#  'esopo',
#  'ester',
#  'euler',
#  'filho',
#  'fabio',
#  'gales',
#  'gauss',
#  'goias',
#  'golfo',
#  'hegel',
#  'intel',
#  'jaime',
#  'japao',
#  'jesus',
#  'jobim',
#  'jorge',
#  'kazuo',
#  'kioto',
#  'klein',
#  'labma',
#  'lages',
#  'laura',
#  'lauro',
#  'lenin',
#  'linda',
#  'linus',
#  'linux',
#  'lucio',
#  'malba',
#  'marco',
#  'maria',
#  'marta',
#  'marte',
#  'mauro',
#  'miami',
#  'minas',
#  'morse',
#  'mario',
#  'media',
#  'natal',
#  'neusa',
#  'nobel',
#  'norte',
#  'paris',
#  'paula',
#  'paulo',
#  'peano',
#  'pedro',
#  'piaui',
#  'porto',
#  'praga',
#  'ramos',
#  'romeu',
#  'rouen',
#  'saara',
#  'santa',
#  'santo',
#  'silva',
#  'souza',
#  'suica',
#  'siria',
#  'sonia',
#  'terra',
#  'texas',
#  'tomas',
#  'uniao',
#  'varig',
#  'vegas',
#  'verbo',
#  'viena',
#  'vista',
#  'venus',
#  'abade',
#  'abafa',
#  'abafe',
#  'abafo',
#  'abafa',
#  'abala',
#  'abale',
#  'abalo',
#  'abala',
#  'abana',
#  'abane',
#  'abano',
#  'abana',
#  'abata',
#  'abate',
#  'abati',
#  'abato',
#  'abate',
#  'abeto',
#  'ablua',
#  'ablui',
#  'abluo',
#  'ablui',
#  'abole',
#  'aboli',
#  'abono',
#  'abram',
#  'abras',
#  'abrem',
#  'abres',
#  'abreu',
#  'abria',
#  'abril',
#  'abrir',
#  'abris',
#  'abriu',
#  'abste',
#  'abusa',
#  'abuse',
#  'abuso',
#  'abusa',
#  'acaba',
#  'acabe',
#  'acabo',
#  'acaba',
#  'acaso',
#  'acata',
#  'acate',
#  'acato',
#  'acata',
#  'acena',
#  'acene',
#  'aceno',
#  'acena',
#  'acesa',
#  'aceso',
#  'aceto',
#  'achai',
#  'acham',
#  'achar',
#  'achas',
#  'achei',
#  'achem',
#  'aches',
#  'achou',
#  'acima',
#  'acode',
#  'acola',
#  'acuai',
#  'acuam',
#  'acuar',
#  'acuas',
#  'acuda',
#  'acudi',
#  'acudo',
#  'acuei',
#  'acuem',
#  'acues',
#  'acuou',
#  'acusa',
#  'acuse',
#  'acuso',
#  'acusa',
#  'adaga',
#  'adega',
#  'adere',
#  'aderi',
#  'adeus',
#  'adiai',
#  'adiam',
#  'adiar',
#  'adias',
#  'adida',
#  'adido',
#  'adiei',
#  'adiem',
#  'adies',
#  'adimo',
#  'adiou',
#  'adira',
#  'adiro',
#  'adira',
#  'adita',
#  'adite',
#  'adito',
#  'adita',
#  'adoce',
#  'adora',
#  'adore',
#  'adoro',
#  'adora',
#  'adota',
#  'adote',
#  'adoto',
#  'adota',
#  'adoca',
#  'adoco',
#  'adoca',
#  'aduba',
#  'adube',
#  'adubo',
#  'aduba',
#  'adula',
#  'adule',
#  'adulo',
#  'adula',
#  'advim',
#  'advir',
#  'advem',
#  'afaga',
#  'afago',
#  'afaga',
#  'afana',
#  'afane',
#  'afano',
#  'afana',
#  'afega',
#  'afere',
#  'aferi',
#  'afeta',
#  'afete',
#  'afeto',
#  'afeta',
#  'afiai',
#  'afiam',
#  'afiar',
#  'afias',
#  'afiei',
#  'afiem',
#  'afies',
#  'afina',
#  'afine',
#  'afino',
#  'afins',
#  'afina',
#  'afiou',
#  'afira',
#  'afiro',
#  'afixa',
#  'afixe',
#  'afixo',
#  'afixa',
#  'aflua',
#  'aflui',
#  'afluo',
#  'aflui',
#  'afoba',
#  'afobe',
#  'afobo',
#  'afoba',
#  'afofa',
#  'afofe',
#  'afofo',
#  'afofa',
#  'afoga',
#  'afogo',
#  'afoga',
#  'afora',
#  'afore',
#  'aforo',
#  'afora',
#  'afros',
#  'aftas',
#  'agiam',
#  'agias',
#  'agido',
#  'agimo',
#  'agira',
#  'agira',
#  'agita',
#  'agite',
#  'agito',
#  'agita',
#  'agora',
#  'aguai',
#  'aguam',
#  'aguar',
#  'aguas',
#  'aguce',
#  'aguda',
#  'agudo',
#  'aguei',
#  'aguem',
#  'agues',
#  'aguou',
#  'aguca',
#  'aguco',
#  'aguca',
#  'ainda',
#  'aires',
#  'ajais',
#  'ajamo',
#  'ajuda',
#  'ajude',
#  'ajudo',
#  'ajuda',
#  'alada',
#  'alado',
#  'alaga',
#  'alago',
#  'alaga',
#  'alcei',
#  'alcem',
#  'alces',
#  'aldea',
#  'alega',
#  'alego',
#  'alega',
#  'alema',
#  'algas',
#  'algoz',
#  'algum',
#  'alhea',
#  'alhos',
#  'aliai',
#  'aliam',
#  'aliar',
#  'alias',
#  'aliei',
#  'aliem',
#  'alies',
#  'alija',
#  'alije',
#  'alijo',
#  'alija',
#  'aliou',
#  'alisa',
#  'alise',
#  'aliso',
#  'alisa',
#  'alias',
#  'almas',
#  'aloca',
#  'aloco',
#  'aloca',
#  'aloja',
#  'aloje',
#  'alojo',
#  'aloja',
#  'aloes',
#  'altar',
#  'altas',
#  'altea',
#  'altos',
#  'aluda',
#  'alude',
#  'aludi',
#  'aludo',
#  'aluga',
#  'alugo',
#  'aluga',
#  'aluna',
#  'aluno',
#  'alvas',
#  'alves',
#  'alvor',
#  'alvos',
#  'alcai',
#  'alcam',
#  'alcar',
#  'alcas',
#  'alcou',
#  'amada',
#  'amado',
#  'amais',
#  'amamo',
#  'amara',
#  'amaro',
#  'amara',
#  'amava',
#  'ambas',
#  'ambos',
#  'ameba',
#  'ameia',
#  'ameis',
#  'amemo',
#  'amena',
#  'ameno',
#  'ameca',
#  'amido',
#  'amiga',
#  'amigo',
#  'amiga',
#  'amima',
#  'amime',
#  'amimo',
#  'amima',
#  'amola',
#  'amole',
#  'amolo',
#  'amola',
#  'amora',
#  'ampla',
#  'amplo',
#  'anais',
#  'ancas',
#  'ancia',
#  'andai',
#  'andam',
#  'andar',
#  'andas',
#  'andei',
#  'andem',
#  'andes',
#  'andor',
#  'andou',
#  'andre',
#  'anela',
#  'anele',
#  'anelo',
#  'anela',
#  'anexa',
#  'anexe',
#  'anexo',
#  'anexa',
#  'anglo',
#  'angra',
#  'anima',
#  'anime',
#  'animo',
#  'anima',
#  'anjos',
#  'anota',
#  'anote',
#  'anoto',
#  'anota',
#  'ansia',
#  'antas',
#  'antes',
#  'antro',
#  'antao',
#  'anual',
#  'anuam',
#  'anuas',
#  'anuem',
#  'anuir',
#  'anuis',
#  'anuiu',
#  'anula',
#  'anule',
#  'anulo',
#  'anula',
#  'anuia',
#  'anuis',
#  'anzol',
#  'aneis',
#  'anoes',
#  'aonde',
#  'aorta',
#  'apaga',
#  'apago',
#  'apaga',
#  'apara',
#  'apare',
#  'aparo',
#  'apara',
#  'apeai',
#  'apear',
#  'apeei',
#  'apega',
#  'apego',
#  'apega',
#  'apeia',
#  'apeie',
#  'apeio',
#  'apela',
#  'apele',
#  'apelo',
#  'apela',
#  'apena',
#  'apene',
#  'apeno',
#  'apena',
#  'apeou',
#  'apita',
#  'apite',
#  'apito',
#  'apita',
#  'apoio',
#  'apoia',
#  'apolo',
#  'aptas',
#  'aptos',
#  'apura',
#  'apure',
#  'apuro',
#  'apura',
#  'apoia',
#  'apoie',
#  'apoio',
#  'aquem',
#  'arada',
#  'arado',
#  'arais',
#  'arame',
#  'aramo',
#  'arara',
#  'arara',
#  'arava',
#  'araca',
#  'arcai',
#  'arcam',
#  'arcar',
#  'arcas',
#  'arcos',
#  'arcou',
#  'ardam',
#  'ardas',
#  'ardei',
#  'ardem',
#  'arder',
#  'ardes',
#  'ardeu',
#  'ardia',
#  'ardil',
#  'ardis',
#  'ardor',
#  'areal',
#  'areia',
#  'areis',
#  'areja',
#  'areje',
#  'arejo',
#  'areja',
#  'aremo',
#  'arena',
#  'arfai',
#  'arfam',
#  'arfar',
#  'arfas',
#  'arfei',
#  'arfem',
#  'arfes',
#  'arfou',
#  'argua',
#  'arguo',
#  'argui',
#  'argui',
#  'argui',
#  'armai',
#  'armam',
#  'armar',
#  'armas',
#  'armei',
#  'armem',
#  'armes',
#  'armou',
#  'aroma',
#  'arpoa',
#  'arpoe',
#  'arpoa',
#  'arpao',
#  'arpoo',
#  'arque',
#  'arrea',
#  'arria',
#  'arrie',
#  'arrio',
#  'arria',
#  'arroz',
#  'artes',
#  'artur',
#  'asila',
#  'asile',
#  'asilo',
#  'asila',
#  'asnos',
#  'aspas',
#  'assai',
#  'assam',
#  'assar',
#  'assas',
#  'assaz',
#  'assei',
#  'assem',
#  'asses',
#  'assea',
#  'assim',
#  'assis',
#  'assoa',
#  'assoe',
#  'assou',
#  'assoa',
#  'assoo',
#  'astro',
#  'ataca',
#  'ataco',
#  'ataca',
#  'atada',
#  'atado',
#  'atais',
#  'atamo',
#  'atara',
#  'atara',
#  'atava',
#  'ateai',
#  'atear',
#  'ateei',
#  'ateia',
#  'ateie',
#  'ateio',
#  'ateis',
#  'atemo',
#  'ateou',
#  'atera',
#  'ateus',
#  'ateve',
#  'atice',
#  'atido',
#  'atina',
#  'atine',
#  'atino',
#  'atina',
#  'atira',
#  'atire',
#  'atiro',
#  'atira',
#  'ativa',
#  'ative',
#  'ativo',
#  'ativa',
#  'atica',
#  'atico',
#  'atica',
#  'atlas',
#  'atola',
#  'atole',
#  'atolo',
#  'atola',
#  'atrai',
#  'atrai',
#  'atriz',
#  'atras',
#  'atuai',
#  'atual',
#  'atuam',
#  'atuar',
#  'atuas',
#  'atuei',
#  'atuem',
#  'atues',
#  'atuns',
#  'atuou',
#  'atura',
#  'ature',
#  'aturo',
#  'atura',
#  'ateia',
#  'atens',
#  'audaz',
#  'aulas',
#  'auras',
#  'autor',
#  'autos',
#  'autua',
#  'autue',
#  'autuo',
#  'autua',
#  'avais',
#  'avara',
#  'avaro',
#  'aveia',
#  'aveio',
#  'avela',
#  'aviai',
#  'aviam',
#  'aviar',
#  'avias',
#  'aviei',
#  'aviem',
#  'avier',
#  'avies',
#  'avimo',
#  'aviou',
#  'avira',
#  'avisa',
#  'avise',
#  'aviso',
#  'avisa',
#  'aviva',
#  'avive',
#  'avivo',
#  'aviva',
#  'aviao',
#  'avens',
#  'axial',
#  'axila',
#  'azara',
#  'azare',
#  'azaro',
#  'azara',
#  'azeda',
#  'azede',
#  'azedo',
#  'azeda',
#  'azias',
#  'azoto',
#  'azuis',
#  'azula',
#  'azule',
#  'azulo',
#  'azula',
#  'acude',
#  'acoes',
#  'aerea',
#  'aereo',
#  'babai',
#  'babam',
#  'babar',
#  'babas',
#  'babei',
#  'babem',
#  'babes',
#  'babou',
#  'babas',
#  'babao',
#  'bacia',
#  'bafos',
#  'bagas',
#  'bagos',
#  'bahia',
#  'baias',
#  'baila',
#  'baile',
#  'bailo',
#  'baila',
#  'baita',
#  'baixa',
#  'baixe',
#  'baixo',
#  'baixa',
#  'baiao',
#  'balam',
#  'balas',
#  'balde',
#  'balem',
#  'bales',
#  'balea',
#  'balia',
#  'balir',
#  'balis',
#  'baliu',
#  'balsa',
#  'balao',
#  'bamba',
#  'bambo',
#  'bambu',
#  'banal',
#  'banca',
#  'banco',
#  'banca',
#  'banda',
#  'bando',
#  'banem',
#  'banes',
#  'banha',
#  'banhe',
#  'banho',
#  'banha',
#  'bania',
#  'banir',
#  'banis',
#  'baniu',
#  'banjo',
#  'baque',
#  'barba',
#  'barca',
#  'barco',
#  'bardo',
#  'bares',
#  'barra',
#  'barre',
#  'barro',
#  'barra',
#  'barao',
#  'bases',
#  'basea',
#  'basta',
#  'baste',
#  'basto',
#  'basta',
#  'batam',
#  'batas',
#  'batei',
#  'batel',
#  'batem',
#  'bater',
#  'bates',
#  'bateu',
#  'batia',
#  'batom',
#  'bauru',
#  'bazar',
#  'bacos',
#  'baias',
#  'beata',
#  'beato',
#  'bebam',
#  'bebas',
#  'bebei',
#  'bebem',
#  'beber',
#  'bebes',
#  'bebeu',
#  'bebia',
#  'bebes',
#  'becas',
#  'becos',
#  'beija',
#  'beije',
#  'beijo',
#  'beija',
#  'beira',
#  'beire',
#  'beiro',
#  'beira',
#  'beico',
#  'belas',
#  'belga',
#  'belos',
#  'bemol',
#  'benta',
#  'bento',
#  'benza',
#  'benze',
#  'benzi',
#  'benzo',
#  'benze',
#  'beque',
#  'berna',
#  'berra',
#  'berre',
#  'berro',
#  'berra',
#  'berco',
#  'besta',
#  'bicai',
#  'bicam',
#  'bicar',
#  'bicas',
#  'bicha',
#  'bicho',
#  'bicos',
#  'bicou',
#  'biela',
#  'bigas',
#  'bingo',
#  'bique',
#  'birra',
#  'bispo',
#  'bisao',
#  'blefa',
#  'blefe',
#  'blefo',
#  'blefa',
#  'bloco',
#  'blusa',
#  'boate',
#  'boato',
#  'bobas',
#  'bobea',
#  'bobos',
#  'bocal',
#  'bocas',
#  'bocha',
#  'bodas',
#  'bodes',
#  'boiai',
#  'boiar',
#  'boiei',
#  'boina',
#  'boiou',
#  'bolai',
#  'bolam',
#  'bolar',
#  'bolas',
#  'boldo',
#  'bolei',
#  'bolem',
#  'boles',
#  'bolha',
#  'bolos',
#  'bolou',
#  'bolsa',
#  'bolso',
#  'bolao',
#  'bomba',
#  'bonde',
#  'bones',
#  'borda',
#  'borde',
#  'bordo',
#  'borda',
#  'borra',
#  'borre',
#  'borro',
#  'borra',
#  'bossa',
#  'bosta',
#  'botai',
#  'botam',
#  'botar',
#  'botas',
#  'botei',
#  'botem',
#  'botes',
#  'botou',
#  'botao',
#  'boxea',
#  'braba',
#  'brabo',
#  'brada',
#  'brade',
#  'brado',
#  'brada',
#  'braga',
#  'brama',
#  'brame',
#  'brami',
#  'bramo',
#  'brama',
#  'brasa',
#  'brava',
#  'bravo',
#  'braca',
#  'braco',
#  'breca',
#  'breco',
#  'breca',
#  'brejo',
#  'breta',
#  'breve',
#  'breve',
#  'brida',
#  'briga',
#  'brigo',
#  'briga',
#  'brins',
#  'brios',
#  'brisa',
#  'brita',
#  'brito',
#  'broas',
#  'broca',
#  'broco',
#  'broca',
#  'bromo',
#  'brota',
#  'brote',
#  'broto',
#  'brota',
#  'bruma',
#  'bruta',
#  'bruto',
#  'bruxa',
#  'bruxo',
#  'bucal',
#  'bucha',
#  'bucho',
#  ...]

# %%
df = pd.DataFrame(palavras)
df.head()
# Out:
#        0
# 0  aarao
# 1  abner
# 2  acaia
# 3  acker
# 4  aires

# %%
df.info()
# Out:
# <bound method DataFrame.info of           0
# 0     aarao
# 1     abner
# 2     acaia
# 3     acker
# 4     aires
# ...     ...
# 6021  unica
# 6022  unico
# 6023  urico
# 6024  uteis
# 6025  utero
#
# [6026 rows x 1 columns]>

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#           0
# 0     aarao
# 1     abner
# 2     acaia
# 3     acker
# 4     aires
# ...     ...
# 6019  unica
# 6020  unico
# 6021  urico
# 6022  uteis
# 6023  utero
#
# [5425 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5427 entries, 0 to 6025
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5427 non-null   object
# dtypes: object(1)
# memory usage: 84.8+ KB

# %%
df.shape
# Out:
# (5427, 1)

# %% [markdown]
# # Função de sortear palavra
# estou usando esse metodo até criar um esquema de pontuação para as palavras
#
# (depois necessário criação de CSV com a pontuação e todo a manipulação de dados, para que no final só fique o filtro!)

# %%
import random

def sorteia_palavra(lista_palavra):
    if len(lista_palavra) == 1:
        return lista_palavra[0]
    else:
        return lista_palavra[random.randint(0,(len(lista_palavra)-1))]

# %%
df.rename(columns = {0:'palavra'}, inplace = True)
df.head()
# Out:
#   palavra
# 0   aarao
# 1   abner
# 2   acaia
# 3   acker
# 4   aires

# %%
df['n_vogais'] = df['palavra'].apply(lambda x: conta_vogais(x)[1])
df['vogais_unicas'] = df['palavra'].apply(lambda x: conta_vogais(x)[0])

df
# Out:
#      palavra  n_vogais  vogais_unicas
# 0      aarao         4              2
# 1      abner         2              2
# 2      acaia         4              2
# 3      acker         2              2
# 4      aires         3              3
# ...      ...       ...            ...
# 6019   unica         3              3
# 6020   unico         3              3
# 6021   urico         3              3
# 6022   uteis         3              3
# 6023   utero         3              3
#
# [5425 rows x 3 columns]

# %% [markdown]
# ----------------------------
#
# normalmente executar até aqui, para assim começar a fazer a apuração das palavras
#
# ----------------------------

# %%
df.sort_values(by=['vogais_unicas','n_vogais'], ascending = False)
# Out:
#      palavra  n_vogais  vogais_unicas
# 15     aecio         4              4
# 114    uniao         4              4
# 196    acuei         4              4
# 219    adiou         4              4
# 276    afiou         4              4
# ...      ...       ...            ...
# 5909   zonzo         2              1
# 5968   ambar         2              1
# 978    brins         1              1
# 1383   clips         1              1
# 5404   trens         1              1
#
# [5425 rows x 3 columns]

# %%
df['letra_0'] = df.palavra.str[0]
df['letra_1'] = df.palavra.str[1]
df['letra_2'] = df.palavra.str[2]
df['letra_3'] = df.palavra.str[3]
df['letra_4'] = df.palavra.str[4]
df.head()
# Out:
#   palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 0   aarao         4              2       a       a       r       a       o
# 1   abner         2              2       a       b       n       e       r
# 2   acaia         4              2       a       c       a       i       a
# 3   acker         2              2       a       c       k       e       r
# 4   aires         3              3       a       i       r       e       s

# %%
melhores_palavras_para_vogais = df[df.vogais_unicas == 4]
#escolher entre essas palavras para começar

# %% [markdown]
# # Startando o termoo no navegador
# aqui seria onde comecei a entender como fazer a busca pela palavra e tentar criar alguma metrica pra achar letras nas strings
#
#
# como proceder com palavras que tem letras repetidas?
#
# aqui podemos fazer uma condição para cada posição estar com a letra certa
#
#
# while pos1 == wrongletter or pos2 == wrongletter or pos3 == wrongletter or pos4 == wrongletter or pos5 == wrongletter
#
# e ir lupando nas tentativas que temos, que aparentemente são 6

# %%
melhores_palavras_para_vogais.shape[0]
# Out:
# 27

# %%
n_escolhido = random.randint(0,melhores_palavras_para_vogais.shape[0])
melhores_palavras_para_vogais.iloc[n_escolhido][0]

#aqui seleciona uma palavra aleatória das que tem mais vogais e adiciona e tira as letras que não serão utilizadas
# Out:
# 'apoie'

# %%
import re
letras_local_errado = 'a'
letras_n_existentes = 'poie'

# %%
str(letras_local_errado) + str(letras_n_existentes)
# Out:
# 'roaiu'

# %%
df.loc[df.palavra == 'nervo',:]
# Out:
#      palavra  n_vogais  vogais_unicas
# 3628   nervo         2              2

# %% [markdown]
# esse é o pensamento inicial, depois que começar o scraping no site e inserção poderemos saber quando acertarmos a posição da letra.
#
# Quando isso acontecer será necessário trocar essa função para adicionar só palavras com letra naquela posição!

# %%
def contem_letras(letras, palavra):
    contador = 0

    for letra in letras: #estava errando aqui ao referencias palavras e não letras que quero que cheque
        if letra in palavra:
            contador += 1

            
    return contador == len(letras)


def tira_palavras_com_letras(letras, palavra):
    contador = 0
    
    for letra in letras:
        if letra in palavra:
            contador += 1
            
    return contador > 0

def lista_de_palavras_possiveis(letras_existentes, letras_n_existentes, lista_de_palavras):
    listinha = []
    

    for palavra in lista_de_palavras:
        if contem_letras(letras_existentes, palavra) == True and tira_palavras_com_letras(letras_n_existentes, palavra) == False:
            listinha.append(palavra)
    
    return listinha

# %%
#talvez terá que chamar essa função + de uma vez, até 4 vezes se pa, dai faz com o contador do scraping
def palavra_com_letras_erradas_nas_posicoes(posicao_letra, lista_palavras):
    nova_lista = []

    for palavra in lista_palavras:
        if palavra[posicao_letra[1]-1] != posicao_letra[0]:
            nova_lista.append(palavra)
    
    return nova_lista

def palavras_com_letras_nas_posicoes(posicao_letra, lista_palavras):
    nova_lista = []

    for palavra in lista_palavras:
        if palavra[posicao_letra[1]-1] == posicao_letra[0]:
            nova_lista.append(palavra)
    
    return nova_lista

# %%
lista_2
# Out:
# ['cagas',
#  'gagas',
#  'gajas',
#  'galas',
#  'gatas',
#  'sagas',
#  'sagaz',
#  'vagas',
#  'zagas']

# %%
letra_aceita_posicao_errada = ['g',1]
lista_2 = palavra_com_letras_erradas_nas_posicoes(letra_aceita_posicao_errada, lista_2)

letra_aceita_posicao_errada = ['s',5]
lista_2 = palavra_com_letras_erradas_nas_posicoes(letra_aceita_posicao_errada, lista_2)

lista_2
# Out:
# ['sagaz']

# %%
novas_palavras = lista_de_palavras_possiveis(letras_local_errado, letras_n_existentes, df.palavra)

numero_sorteado = random.randint(0,len(novas_palavras))
palavra_sorteada = novas_palavras[numero_sorteado]
palavra_sorteada
# Out:
# 'muram'

# %%
novas_palavras = lista_de_palavras_possiveis(letras_local_errado, letras_n_existentes, df.palavra)

# %%
novas_palavras
# Out:
# ['artur',
#  'bagda',
#  'bangu',
#  'carla',
#  'gauss',
#  'labma',
#  'laura',
#  'malba',
#  'marta',
#  'natal',
#  'saara',
#  'santa',
#  'abafa',
#  'abala',
#  'abana',
#  'abata',
#  'ablua',
#  'abram',
#  'abras',
#  'abusa',
#  'acaba',
#  'acata',
#  'acham',
#  'achar',
#  'achas',
#  'acuam',
#  'acuar',
#  'acuas',
#  'acuda',
#  'acusa',
#  'adaga',
#  'aduba',
#  'adula',
#  'afaga',
#  'afana',
#  'aflua',
#  'aftas',
#  'aguam',
#  'aguar',
#  'aguas',
#  'aguda',
#  'aguca',
#  'ajuda',
#  'alada',
#  'alaga',
#  'algas',
#  'algum',
#  'almas',
#  'altar',
#  'altas',
#  'aluda',
#  'aluga',
#  'aluna',
#  'alvas',
#  'alcam',
#  'alcar',
#  'alcas',
#  'amada',
#  'amara',
#  'amava',
#  'ambas',
#  'ancas',
#  'andam',
#  'andar',
#  'andas',
#  'angra',
#  'antas',
#  'anual',
#  'anuam',
#  'anuas',
#  'anula',
#  'arada',
#  'arara',
#  'arava',
#  'araca',
#  'arcam',
#  'arcar',
#  'arcas',
#  'ardam',
#  'ardas',
#  'arfam',
#  'arfar',
#  'arfas',
#  'argua',
#  'armam',
#  'armar',
#  'armas',
#  'assam',
#  'assar',
#  'assas',
#  'assaz',
#  'ataca',
#  'atada',
#  'atara',
#  'atava',
#  'atlas',
#  'atras',
#  'atual',
#  'atuam',
#  'atuar',
#  'atuas',
#  'atuns',
#  'atura',
#  'audaz',
#  'aulas',
#  'auras',
#  'autua',
#  'avara',
#  'azara',
#  'azula',
#  'babam',
#  'babar',
#  'babas',
#  'bagas',
#  'balam',
#  'balas',
#  'balsa',
#  'bamba',
#  'bambu',
#  'banal',
#  'banca',
#  'banda',
#  'banha',
#  'barba',
#  'barca',
#  'barra',
#  'basta',
#  'batam',
#  'batas',
#  'bauru',
#  'bazar',
#  'blusa',
#  'braba',
#  'brada',
#  'braga',
#  'brama',
#  'brasa',
#  'brava',
#  'braca',
#  'bruma',
#  'bruta',
#  'bruxa',
#  'bucal',
#  'bucha',
#  'bufam',
#  'bufar',
#  'bufas',
#  'bulam',
#  'bulas',
#  'bunda',
#  'burla',
#  'burra',
#  'busca',
#  'cabra',
#  'cacas',
#  'cagam',
#  'cagar',
#  'cagas',
#  'calam',
#  'calar',
#  'calas',
#  'calca',
#  'calda',
#  'calha',
#  'calma',
#  'calva',
#  'camas',
#  'canal',
#  'canas',
#  'canga',
#  'canja',
#  'cansa',
#  'canta',
#  'caras',
#  'carga',
#  'carta',
#  'casal',
#  'casam',
#  'casar',
#  'casas',
#  'casca',
#  'cassa',
#  'casta',
#  'catam',
#  'catar',
#  'catas',
#  'cauda',
#  'causa',
#  'cauta',
#  'cavam',
#  'cavar',
#  'cavas',
#  'cacam',
#  'cacar',
#  'chaga',
#  'chama',
#  'chata',
#  'chuta',
#  'chuva',
#  'clama',
#  'clara',
#  'clava',
#  'crava',
#  'cruas',
#  'cruza',
#  'cubas',
#  'cubra',
#  'cucas',
#  'cujas',
#  'culta',
#  'cunha',
#  'curam',
#  'curar',
#  'curas',
#  'cursa',
#  'curta',
#  'curva',
#  'custa',
#  'dadas',
#  'damas',
#  'danam',
#  'danar',
#  'danas',
#  'danca',
#  'daras',
#  'datam',
#  'datar',
#  'datas',
#  'davam',
#  'davas',
#  'draga',
#  'drama',
#  'dubla',
#  'ducha',
#  'dumas',
#  'dunas',
#  'dunga',
#  'duram',
#  'durar',
#  'duras',
#  'durma',
#  'facas',
#  'fadas',
#  'falam',
#  'falar',
#  'falas',
#  'falda',
#  'falha',
#  'falsa',
#  'falta',
#  'famas',
#  'farda',
#  'farra',
#  'farsa',
#  'farta',
#  'faras',
#  'fatal',
#  'fauna',
#  'favas',
#  'facam',
#  'fluam',
#  'fluas',
#  'fraca',
#  'fraga',
#  'fruam',
#  'fruas',
#  'fruta',
#  'fugas',
#  'fugaz',
#  'fujam',
#  'fujas',
#  'fumam',
#  'fumar',
#  'fumas',
#  'funda',
#  'funga',
#  'furam',
#  'furar',
#  'furas',
#  'furna',
#  'furta',
#  'fucam',
#  'fucar',
#  'fucas',
#  'gabam',
#  'gabar',
#  'gabas',
#  'gagas',
#  'gajas',
#  'galas',
#  'galga',
#  'gamba',
#  'ganha',
#  'garfa',
#  'garra',
#  'garca',
#  'gasta',
#  'gatas',
#  'gazua',
#  'grafa',
#  'grama',
#  'grana',
#  'grata',
#  'graus',
#  'grava',
#  'graxa',
#  'graca',
#  'gruda',
#  'gruta',
#  'hajam',
#  'hajas',
#  'haras',
#  'hulha',
#  'hurra',
#  'jacas',
#  'janta',
#  'jarda',
#  'jarra',
#  'jaula',
#  'jazam',
#  'jazas',
#  'jubas',
#  'judas',
#  'julga',
#  'junta',
#  'juram',
#  'jurar',
#  'juras',
#  'justa',
#  'lacra',
#  'ladra',
#  'lagar',
#  'lamba',
#  'lanca',
#  'larga',
#  'larva',
#  'lasca',
#  'latas',
#  'lauda',
#  'lavam',
#  'lavar',
#  'lavas',
#  'lavra',
#  'lacam',
#  'lacar',
#  'lacas',
#  'lhama',
#  'lucas',
#  'lucra',
#  'lugar',
#  'lulas',
#  'lunar',
#  'lusas',
#  'lutam',
#  'lutar',
#  'lutas',
#  'luvas',
#  'luzam',
#  'luzas',
#  'macas',
#  'magma',
#  'magna',
#  'magra',
#  'malas',
#  'malha',
#  'malta',
#  'mamam',
#  'mamar',
#  'mamas',
#  'manas',
#  'manca',
#  'manda',
#  'manga',
#  'manha',
#  'manja',
#  'mansa',
#  'manta',
#  'marca',
#  'marra',
#  'masca',
#  'massa',
#  'matam',
#  'matar',
#  'matas',
#  'mudam',
#  'mudar',
#  'mudas',
#  'mujam',
#  'mujas',
#  'mulas',
#  'multa',
#  'mural',
#  'muram',
#  'murar',
#  'muras',
#  'musas',
#  'musca',
#  'mutua',
#  'nabla',
#  'nadam',
#  'nadar',
#  'nadas',
#  'nafta',
#  'nanam',
#  'nanar',
#  'nanas',
#  'narra',
#  'nasal',
#  'nasca',
#  'natas',
#  'nauta',
#  'naval',
#  'nulas',
#  'numas',
#  'nunca',
#  'nutra',
#  'racha',
#  'radar',
#  'rajam',
#  'rajar',
#  'rajas',
#  'ralam',
#  'ralar',
#  'ralas',
#  'ralha',
#  'ranja',
#  'raras',
#  'rasas',
#  'rasga',
#  'ratas',
#  'racas',
#  'rubra',
#  'rufam',
#  'rufar',
#  'rufas',
#  'rugam',
#  'rugar',
#  'rugas',
#  'rujam',
#  'rujas',
#  'rumam',
#  'rumar',
#  'rumas',
#  'rural',
#  'rusga',
#  'russa',
#  'sacam',
#  'sacar',
#  'sacas',
#  'sacra',
#  'safam',
#  'safar',
#  'safas',
#  'safra',
#  'sagas',
#  'sagaz',
#  'sagra',
#  'salas',
#  'salda',
#  'salga',
#  'salsa',
#  'salta',
#  'salva',
#  'samba',
#  'sanam',
#  'sanar',
#  'sanas',
#  'sanha',
#  'saram',
#  'sarar',
#  'saras',
#  'sarda',
#  'sarna',
#  'sarca',
#  'sauda',
#  'sauna',
#  'sauva',
#  'suada',
#  'suara',
#  'suava',
#  'subam',
#  'subas',
#  'sugam',
#  'sugar',
#  'sugas',
#  'sujam',
#  'sujar',
#  'sujas',
#  'sulca',
#  'sulfa',
#  'sumam',
#  'sumas',
#  'sunga',
#  'surda',
#  'surja',
#  'surra',
#  'surta',
#  'susta',
#  'tabas',
#  'tacam',
#  'tacar',
#  'tacas',
#  'tacha',
#  'talas',
#  'talha',
#  'tanga',
#  'tanja',
#  'tanta',
#  'taras',
#  'tarda',
#  'tarja',
#  'tatua',
#  'tatus',
#  'taxam',
#  'taxar',
#  'taxas',
#  'traga',
#  'traja',
#  'trama',
#  'trara',
#  'trata',
#  'trava',
#  'traca',
#  'trufa',
#  'truta',
#  'tumba',
#  'turba',
#  'turca',
#  'turma',
#  'turva',
#  'tussa',
#  'tabua',
#  'ufana',
#  'ultra',
#  'ulula',
#  'unhas',
#  'untam',
#  'untar',
#  'untas',
#  'urdam',
#  'urdas',
#  'urjam',
#  'urjas',
#  'urnas',
#  'urram',
#  'urrar',
#  'urras',
#  'ursas',
#  'usada',
#  'usara',
#  'usava',
#  'usual',
#  'usura',
#  'vacas',
#  'vagam',
#  'vagar',
#  'vagas',
#  'valas',
#  'valha',
#  'valsa',
#  'varam',
#  'varar',
#  'varas',
#  'varra',
#  'vasta',
#  'vazam',
#  'vazar',
#  'vazas',
#  'vulva',
#  'xaras',
#  'xucra',
#  'zagas',
#  'zanga',
#  'zanza',
#  'zumba',
#  'zunam',
#  'zunas',
#  'zurra',
#  'agata',
#  'album',
#  'ardua',
#  'ambar']

# %%
def palavras_com_letras_nas_posicoes(posicao_letra, lista_palavras):
    nova_lista = []

    for palavra in lista_palavras:
        if palavra[posicao_letra[1]-1] == posicao_letra[0]: 
            #aqui parece confuso mas ele recebe a posição assim
            # posição[letra,posição_letra]
            nova_lista.append(palavra)
    
    return nova_lista

# %%
def sorteia_palavra(lista_palavra):
    return lista_palavra[random.randint(0,len(lista_palavra))]

# %%
len(nova_lista)
# Out:
# 396

# %%
novas_letras_n_aceitas = 'murm'
novas_letras_aceitas = ''
posicao_4 = ['a',4]


lista_2 = lista_de_palavras_possiveis(novas_letras_aceitas, novas_letras_n_aceitas, novas_palavras)
lista_2 = palavras_com_letras_nas_posicoes(posicao_4, lista_2)
lista_2
# Out:
# ['natal',
#  'achas',
#  'aftas',
#  'algas',
#  'altas',
#  'alvas',
#  'alcas',
#  'ancas',
#  'andas',
#  'antas',
#  'assas',
#  'assaz',
#  'atlas',
#  'babas',
#  'bagas',
#  'balas',
#  'banal',
#  'batas',
#  'cacas',
#  'cagas',
#  'calas',
#  'canal',
#  'canas',
#  'casal',
#  'casas',
#  'catas',
#  'cavas',
#  'dadas',
#  'danas',
#  'datas',
#  'davas',
#  'facas',
#  'fadas',
#  'falas',
#  'fatal',
#  'favas',
#  'gabas',
#  'gagas',
#  'gajas',
#  'galas',
#  'gatas',
#  'hajas',
#  'jacas',
#  'jazas',
#  'latas',
#  'lavas',
#  'lacas',
#  'nadas',
#  'nanas',
#  'nasal',
#  'natas',
#  'naval',
#  'sacas',
#  'safas',
#  'sagas',
#  'sagaz',
#  'salas',
#  'sanas',
#  'tabas',
#  'tacas',
#  'talas',
#  'taxas',
#  'vacas',
#  'vagas',
#  'valas',
#  'vazas',
#  'zagas']

# %%
sorteia_palavra(lista_2)
# Out:
# 'gabas'

# %%
#segunda vez rodando

novas_letras_n_aceitas = 'b'
novas_letras_aceitas = 'gs'
posicao_4 = ['a',2]


lista_2 = lista_de_palavras_possiveis(novas_letras_aceitas, novas_letras_n_aceitas, lista_2)
lista_2 = palavras_com_letras_nas_posicoes(posicao_4, lista_2)
lista_2
# Out:
# ['cagas',
#  'gagas',
#  'gajas',
#  'galas',
#  'gatas',
#  'sagas',
#  'sagaz',
#  'vagas',
#  'zagas']

# %%
lista_2 = lista_de_palavras_possiveis(novas_letras_aceitas, novas_letras_n_aceitas, nova_lista)
lista_2
# Out:
# ['bagda',
#  'carla',
#  'labma',
#  'laura',
#  'malba',
#  'marta',
#  'saara',
#  'santa',
#  'abafa',
#  'abafa',
#  'abala',
#  'abala',
#  'abana',
#  'abana',
#  'abata',
#  'ablua',
#  'abusa',
#  'abusa',
#  'acaba',
#  'acaba',
#  'acata',
#  'acata',
#  'acuda',
#  'acusa',
#  'acusa',
#  'adaga',
#  'aduba',
#  'aduba',
#  'adula',
#  'adula',
#  'afaga',
#  'afaga',
#  'afana',
#  'afana',
#  'aflua',
#  'aguda',
#  'aguca',
#  'aguca',
#  'ajuda',
#  'ajuda',
#  'alada',
#  'alaga',
#  'alaga',
#  'aluda',
#  'aluga',
#  'aluga',
#  'aluna',
#  'amada',
#  'amara',
#  'amara',
#  'amava',
#  'angra',
#  'anula',
#  'anula',
#  'arada',
#  'arara',
#  'arara',
#  'arava',
#  'araca',
#  'argua',
#  'ataca',
#  'ataca',
#  'atada',
#  'atara',
#  'atara',
#  'atava',
#  'atura',
#  'atura',
#  'autua',
#  'autua',
#  'avara',
#  'azara',
#  'azara',
#  'azula',
#  'azula',
#  'balsa',
#  'bamba',
#  'banca',
#  'banca',
#  'banda',
#  'banha',
#  'banha',
#  'barba',
#  'barca',
#  'barra',
#  'barra',
#  'basta',
#  'basta',
#  'blusa',
#  'braba',
#  'brada',
#  'brada',
#  'braga',
#  'brama',
#  'brama',
#  'brasa',
#  'brava',
#  'braca',
#  'bruma',
#  'bruta',
#  'bruxa',
#  'bucha',
#  'bunda',
#  'bunda',
#  'burla',
#  'burla',
#  'burra',
#  'busca',
#  'busca',
#  'cabra',
#  'calca',
#  'calca',
#  'calda',
#  'calha',
#  'calha',
#  'calma',
#  'calva',
#  'calca',
#  'calca',
#  'canaa',
#  'canga',
#  'canja',
#  'cansa',
#  'cansa',
#  'canta',
#  'canta',
#  'carga',
#  'carta',
#  'casca',
#  'cassa',
#  'cassa',
#  'casta',
#  'cauda',
#  'causa',
#  'causa',
#  'cauta',
#  'chaga',
#  'chaga',
#  'chama',
#  'chama',
#  'chata',
#  'chuta',
#  'chuta',
#  'chuva',
#  'clama',
#  'clama',
#  'clara',
#  'clava',
#  'crava',
#  'crava',
#  'cruza',
#  'cruza',
#  'cubra',
#  'culta',
#  'cunha',
#  'cunha',
#  'cursa',
#  'cursa',
#  'curta',
#  'curva',
#  'curva',
#  'custa',
#  'custa',
#  'danca',
#  'danca',
#  'draga',
#  'draga',
#  'drama',
#  'dubla',
#  'dubla',
#  'ducha',
#  'dunga',
#  'durma',
#  'falda',
#  'falha',
#  'falha',
#  'falsa',
#  'falta',
#  'falta',
#  'farda',
#  'farra',
#  'farsa',
#  'farta',
#  'farta',
#  'fauna',
#  'fraca',
#  'fraga',
#  'fruta',
#  'funda',
#  'funda',
#  'funga',
#  'funga',
#  'furna',
#  'furta',
#  'furta',
#  'galga',
#  'galga',
#  'gamba',
#  'ganha',
#  'ganha',
#  'garfa',
#  'garfa',
#  'garra',
#  'garca',
#  'gasta',
#  'gasta',
#  'gazua',
#  'grafa',
#  'grafa',
#  'grama',
#  'grana',
#  'grata',
#  'grava',
#  'grava',
#  'graxa',
#  'graca',
#  'gruda',
#  'gruda',
#  'gruta',
#  'hulha',
#  'hurra',
#  'janta',
#  'janta',
#  'jarda',
#  'jarra',
#  'jaula',
#  'julga',
#  'julga',
#  'junta',
#  'junta',
#  'justa',
#  'lacra',
#  'lacra',
#  'ladra',
#  'ladra',
#  'lamba',
#  'lanca',
#  'lanca',
#  'larga',
#  'larga',
#  'larva',
#  'lasca',
#  'lasca',
#  'lauda',
#  'lavra',
#  'lavra',
#  'lhama',
#  'lucra',
#  'lucra',
#  'magma',
#  'magna',
#  'magra',
#  'malha',
#  'malha',
#  'malta',
#  'manca',
#  'manca',
#  'manda',
#  'manda',
#  'manga',
#  'manha',
#  'manha',
#  'manja',
#  'manja',
#  'mansa',
#  'manta',
#  'marca',
#  'marca',
#  'marra',
#  'marta',
#  'masca',
#  'masca',
#  'massa',
#  'multa',
#  'multa',
#  'musca',
#  'mutua',
#  'nabla',
#  'nafta',
#  'narra',
#  'narra',
#  'nasca',
#  'nauta',
#  'nunca',
#  'nutra',
#  'racha',
#  'racha',
#  'ralha',
#  'ralha',
#  'ranja',
#  'rasga',
#  'rasga',
#  'rubra',
#  'rusga',
#  'russa',
#  'saara',
#  'sacra',
#  'safra',
#  'sagra',
#  'sagra',
#  'salda',
#  'salda',
#  'salga',
#  'salga',
#  'salsa',
#  'salta',
#  'salta',
#  'salva',
#  'salva',
#  'samba',
#  'samba',
#  'sanha',
#  'santa',
#  'sarda',
#  'sarna',
#  'sarca',
#  'sauda',
#  'sauna',
#  'sauda',
#  'sauva',
#  'suada',
#  'suara',
#  'suara',
#  'suava',
#  'sulca',
#  'sulca',
#  'sulfa',
#  'sunga',
#  'surda',
#  'surja',
#  'surra',
#  'surra',
#  'surta',
#  'susta',
#  'susta',
#  'tacha',
#  'tacha',
#  'talha',
#  'talha',
#  'tanga',
#  'tanja',
#  'tanta',
#  'tanta',
#  'tarda',
#  'tarda',
#  'tarja',
#  'tatua',
#  'tatua',
#  'traga',
#  'traga',
#  'traja',
#  'traja',
#  'trama',
#  'trara',
#  'trata',
#  'trata',
#  'trava',
#  'trava',
#  'traca',
#  'traca',
#  'trufa',
#  'truta',
#  'tumba',
#  'turba',
#  'turba',
#  'turca',
#  'turma',
#  'turva',
#  'turva',
#  'tussa',
#  'tabua',
#  'ufana',
#  'ufana',
#  'ultra',
#  'ulula',
#  'ulula',
#  'usada',
#  'usara',
#  'usara',
#  'usava',
#  'usura',
#  'valha',
#  'valsa',
#  'varra',
#  'vasta',
#  'vulva',
#  'xucra',
#  'zanga',
#  'zanga',
#  'zanza',
#  'zanza',
#  'zumba',
#  'zurra',
#  'zurra',
#  'agata',
#  'ardua']

# %%
#sempre necessário ja excluir a palavra

lista_2.remove(palavra_sorteada)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-227-452540fdac30> in <module>
#       1 #sempre necessário ja excluir a palavra
#       2
# ----> 3 lista_2.remove(palavra_sorteada)
#
# ValueError: list.remove(x): x not in list

# %%
novas_letras_n_aceitas = ''
novas_letras_aceitas = ''

posicao_2 = ['',2]
posicao_3 = ['',3]
posicao_4 = ['a',4]
posicao_5 = ['',5]

#lista_2 = palavras_com_letras_nas_posicoes(posicao_2, lista_2)
#lista_2 = palavras_com_letras_nas_posicoes(posicao_3, lista_2)
lista_2 = palavras_com_letras_nas_posicoes(posicao_4, lista_2)

lista_2 = lista_de_palavras_possiveis(novas_letras_aceitas, novas_letras_n_aceitas, lista_2)
lista_2
# Out:
# ['canaa']

# %% [markdown]
# teoricamente aqui conseguimos resolver mais ou menos o termo, agora é pesquisar novas metricas e testar nos outros dias, melhorando o filtro e a seleção, também seria legal rankear as palavras mais comuns e ver se conseguimos gerar um peso de palavras
#
# - trabalhar em melhorar as funções e como elas vão conversar entre elas

# %%
tira_palavras_com_letras(letras_n_existentes, teste)
# Out:
# False

# %%
contem_letras(letras_n_existentes, teste)
# Out:
# False

# %%
listinha = []

for palavra in df.palavra:
    if contem_letras(letras_local_errado, palavra) == True and tira_palavras_com_letras(letras_n_existentes, palavra) == False:
        #print(palavra)
        listinha.append(palavra)

# %%
listinha
# Out:
# ['jorge',
#  'morse',
#  'norte',
#  'pedro',
#  'porto',
#  'verbo',
#  'berro',
#  'berco',
#  'borde',
#  'bordo',
#  'borre',
#  'borro',
#  'breco',
#  'brejo',
#  'broco',
#  'bromo',
#  'brote',
#  'broto',
#  'boers',
#  'cedro',
#  'cerco',
#  'cerol',
#  'cerro',
#  'certo',
#  'cervo',
#  'cetro',
#  'chore',
#  'choro',
#  'clero',
#  'cloro',
#  'cobre',
#  'cobro',
#  'cofre',
#  'comer',
#  'corem',
#  'cores',
#  'corno',
#  'coroe',
#  'coros',
#  'corpo',
#  'corre',
#  'corro',
#  'corte',
#  'corto',
#  'corvo',
#  'coroo',
#  'coser',
#  'cozer',
#  'credo',
#  'cremo',
#  'crome',
#  'cromo',
#  'depor',
#  'dermo',
#  'dobre',
#  'dobro',
#  'dores',
#  'dorme',
#  'dorso',
#  'dreno',
#  'drogo',
#  'entro',
#  'ereto',
#  'ermos',
#  'erode',
#  'erodo',
#  'erros',
#  'expor',
#  'fedor',
#  'feroz',
#  'ferro',
#  'fervo',
#  'force',
#  'forem',
#  'fores',
#  'forje',
#  'forjo',
#  'forme',
#  'formo',
#  'forno',
#  'foros',
#  'forre',
#  'forro',
#  'forte',
#  'forco',
#  'freso',
#  'freto',
#  'frevo',
#  'genro',
#  'gordo',
#  'gorem',
#  'gores',
#  'gorro',
#  'grego',
#  'herdo',
#  'honre',
#  'honro',
#  'horto',
#  'jorre',
#  'jorro',
#  'lerdo',
#  'lermo',
#  'logre',
#  'logro',
#  'lorde',
#  'medro',
#  'melro',
#  'menor',
#  'meros',
#  'metro',
#  'morde',
#  'mordo',
#  'morem',
#  'mores',
#  'morno',
#  'morre',
#  'morro',
#  'morte',
#  'morto',
#  'motor',
#  'mover',
#  'negro',
#  'nervo',
#  'nobre',
#  'obter',
#  'ombro',
#  'onere',
#  'onero',
#  'opere',
#  'opero',
#  'orcem',
#  'orces',
#  'ordem',
#  'oremo',
#  'orgem',
#  'orges',
#  'orlem',
#  'orles',
#  'ornem',
#  'ornes',
#  'perco',
#  'perto',
#  'pobre',
#  'poder',
#  'porco',
#  'porem',
#  'pores',
#  'poros',
#  'porre',
#  'porte',
#  'potro',
#  'prego',
#  'prelo',
#  'premo',
#  'prepo',
#  'preso',
#  'preto',
#  'prezo',
#  'preco',
#  'prole',
#  'propo',
#  'prove',
#  'provo',
#  'reboe',
#  'reboo',
#  'redor',
#  'regro',
#  'remoe',
#  'remos',
#  'remoo',
#  'rendo',
#  'repor',
#  'repos',
#  'repoe',
#  'resto',
#  'retos',
#  'robos',
#  'rocem',
#  'roces',
#  'rodem',
#  'rodes',
#  'rodos',
#  'roemo',
#  'rogem',
#  'roges',
#  'rogos',
#  'rolem',
#  'roles',
#  'rolos',
#  'rombo',
#  'rompe',
#  'rompo',
#  'ronco',
#  'ronde',
#  'rondo',
#  'rosne',
#  'rosno',
#  'rosto',
#  'rotos',
#  'roxos',
#  'roseo',
#  'serro',
#  'servo',
#  'setor',
#  'sobre',
#  'sobro',
#  'sofre',
#  'sofro',
#  'sogro',
#  'sopre',
#  'sopro',
#  'soros',
#  'sorte',
#  'sorve',
#  'sorvo',
#  'temor',
#  'tenor',
#  'tenro',
#  'termo',
#  'terno',
#  'terco',
#  'torce',
#  'torne',
#  'torno',
#  'toros',
#  'torpe',
#  'torre',
#  'torro',
#  'torto',
#  'torco',
#  'treco',
#  'tremo',
#  'treno',
#  'trepo',
#  'trevo',
#  'troce',
#  'troco',
#  'trono',
#  'trote',
#  'troto',
#  'verso',
#  'verto',
#  'vetor',
#  'xerox',
#  'zeros']

# %%
contem_letras(letras_n_existentes, 'aarao')
# Out:
# False

# %%
for palavra in df.palavras:
    print(palavra)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-174-df97dae0ba51> in <module>
# ----> 1 for palavra in df.palavras:
#       2     print(palavra)
#
# ~\anaconda3\envs\dh\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'palavras'

# %% [markdown]
# -----------------------------
#
# Palavras excluidas do dicionario baixado da usp:
# - lermo
# - canaa
#
# -----------------------------

# %%
#teste letreco
letras_local_errado = ''
letras_n_existentes = 'ape'

novas_palavras = lista_de_palavras_possiveis(letras_local_errado, letras_n_existentes, df.palavra)

# %%
novas_palavras
# Out:
# ['bruno',
#  'chico',
#  'couto',
#  'filho',
#  'golfo',
#  'jobim',
#  'kioto',
#  'linus',
#  'linux',
#  'lucio',
#  'bicho',
#  'bicos',
#  'bicou',
#  'bingo',
#  'bloco',
#  'bobos',
#  'boiou',
#  'boldo',
#  'bolos',
#  'bolou',
#  'bolso',
#  'bordo',
#  'borro',
#  'botou',
#  'brigo',
#  'brins',
#  'brios',
#  'brito',
#  'broco',
#  'bromo',
#  'broto',
#  'bruto',
#  'bruxo',
#  'bucho',
#  'bufou',
#  'bulbo',
#  'bulir',
#  'bulis',
#  'buliu',
#  'bumbo',
#  'bundo',
#  'burgo',
#  'burlo',
#  'burro',
#  'busco',
#  'busto',
#  'buxos',
#  'bilis',
#  'bonus',
#  'buzio',
#  'chiou',
#  'choco',
#  'choro',
#  'chovi',
#  'chovo',
#  'chuto',
#  'ciclo',
#  'cifro',
#  'cinco',
#  'cindi',
#  'cindo',
#  'cingi',
#  'cinjo',
#  'cinto',
#  'cioso',
#  'circo',
#  'cisco',
#  'cismo',
#  'citou',
#  'civil',
#  'civis',
#  'cloro',
#  'cobri',
#  'cobro',
#  'cocho',
#  'cocos',
#  'coibi',
#  'coito',
#  'colhi',
#  'colho',
#  'colou',
#  'comum',
#  'conto',
#  'corno',
#  'coros',
#  'corou',
#  'corri',
#  'corro',
#  'corto',
#  'corvo',
#  'coroo',
#  'cosmo',
#  'cotou',
#  'couro',
#  'coxim',
#  'coxos',
#  'cocou',
#  'coibo',
#  'crido',
#  'criou',
#  'crivo',
#  'cromo',
#  'cruzo',
#  'cubos',
#  'cubro',
#  'cucos',
#  'cuido',
#  'cujos',
#  'cujus',
#  'culto',
#  'cunho',
#  'curou',
#  'curso',
#  'curti',
#  'curto',
#  'curvo',
#  'custo',
#  'cilio',
#  'cirio',
#  'colon',
#  'cutis',
#  'digno',
#  'dilui',
#  'diluo',
#  'diodo',
#  'disco',
#  'disso',
#  'disto',
#  'ditos',
#  'ditou',
#  'dobro',
#  'doido',
#  'domou',
#  'donos',
#  'dormi',
#  'dorso',
#  'dosou',
#  'dotou',
#  'douro',
#  'douto',
#  'drogo',
#  'dublo',
#  'durmo',
#  'duros',
#  'durou',
#  'dutos',
#  'dubio',
#  'ficho',
#  'ficou',
#  'figos',
#  'filio',
#  'filmo',
#  'filou',
#  'finco',
#  'findo',
#  'fingi',
#  'finjo',
#  'finos',
#  'finto',
#  'firmo',
#  'fisco',
#  'fisgo',
#  'fitou',
#  'fixos',
#  'fixou',
#  'floco',
#  'flori',
#  'fluir',
#  'fluis',
#  'fluiu',
#  'fluxo',
#  'focos',
#  'focou',
#  'fofos',
#  'fogos',
#  'folgo',
#  'fomos',
#  'forjo',
#  'formo',
#  'forno',
#  'foros',
#  'forro',
#  'forco',
#  'fosco',
#  'fosso',
#  'fotos',
#  'frigi',
#  'frijo',
#  'frios',
#  'friso',
#  'frito',
#  'fruir',
#  'fruis',
#  'fruiu',
#  'fruto',
#  'fugir',
#  'fugis',
#  'fugiu',
#  'fujir',
#  'fujis',
#  'fujiu',
#  'fulgi',
#  'fumou',
#  'fundi',
#  'fundo',
#  'fungo',
#  'funil',
#  'funis',
#  'furor',
#  'furos',
#  'furou',
#  'furto',
#  'fusco',
#  'fusos',
#  'fuzil',
#  'fuzis',
#  'fucou',
#  'forum',
#  'futil',
#  'gingo',
#  'giros',
#  'girou',
#  'globo',
#  'gloso',
#  'gnomo',
#  'gomos',
#  'gongo',
#  'gonzo',
#  'gordo',
#  'gorou',
#  'gorro',
#  'gosto',
#  'gozos',
#  'gozou',
#  'grifo',
#  'grilo',
#  'grito',
#  'grudo',
#  'guiou',
#  'guizo',
#  'guris',
#  'godos',
#  'hindu',
#  'hinos',
#  'honro',
#  'horto',
#  'humor',
#  'hunos',
#  'humus',
#  'idoso',
#  'ilhou',
#  'iludi',
#  'iludo',
#  'imito',
#  'imolo',
#  'incho',
#  'incoo',
#  'induz',
#  'inflo',
#  'inibi',
#  'inibo',
#  'inovo',
#  'insto',
#  'intui',
#  'intuo',
#  'irmos',
#  'isolo',
#  'istmo',
#  'jogos',
#  'jogou',
#  'jorro',
#  'judio',
#  'julgo',
#  'julho',
#  'junco',
#  'junho',
#  'junto',
#  'juros',
#  'jurou',
#  'justo',
#  'juizo',
#  'licor',
#  'lidos',
#  'lidou',
#  'ligou',
#  'limbo',
#  'limou',
#  'lindo',
#  'linho',
#  'lisos',
#  'listo',
#  'litro',
#  'livro',
#  'lixou',
#  'lobos',
#  'locou',
#  'logro',
#  'loiro',
#  'lombo',
#  'longo',
#  'lotou',
#  'louco',
#  'louro',
#  'louvo',
#  'lucro',
#  'lusos',
#  'lutou',
#  'luxos',
#  'luzir',
#  'luzis',
#  'luziu',
#  'lirio',
#  'litio',
#  'lotus',
#  'micos',
#  'micro',
#  'migro',
#  'mijou',
#  'milho',
#  'mimos',
#  'mimou',
#  'minis',
#  'minou',
#  'minto',
#  'miolo',
#  'mirou',
#  'misto',
#  'mitos',
#  'mixos',
#  'mixto',
#  'miudo',
#  'modos',
#  'mofou',
#  'mogno',
#  'mogol',
#  'moldo',
#  'molho',
#  'momos',
#  'monto',
#  'mordi',
#  'mordo',
#  'morno',
#  'morou',
#  'morri',
#  'morro',
#  'morto',
#  'motor',
#  'motos',
#  'mouro',
#  'mocos',
#  'moido',
#  'mucos',
#  'mudos',
#  'mudou',
#  'mugir',
#  'mugis',
#  'mugiu',
#  'muito',
#  'multi',
#  'multo',
#  'mundo',
#  'munir',
#  'munis',
#  'muniu',
#  'muros',
#  'murou',
#  'murro',
#  'musco',
#  'musgo',
#  'mutuo',
#  'nicho',
#  'ninho',
#  'ninou',
#  'nisso',
#  'nisto',
#  'nitro',
#  'noivo',
#  'nosso',
#  'notou',
#  'novos',
#  'nulos',
#  'nutri',
#  'nutro',
#  'obsto',
#  'obvio',
#  'odiou',
#  'olhos',
#  'olhou',
#  'ombro',
#  'omiti',
#  'omito',
#  'orlou',
#  'ornou',
#  'orcou',
#  'ossos',
#  'ouros',
#  'ousou',
#  'outro',
#  'ouvir',
#  'ouvis',
#  'ouviu',
#  'ovino',
#  'oxido',
#  'quilo',
#  'quito',
#  'ricos',
#  'rifou',
#  'rigor',
#  'rijos',
#  'rimos',
#  'rimou',
#  'rindo',
#  'rirmo',
#  'risco',
#  'risos',
#  'ritmo',
#  'ritos',
#  'robos',
#  'rodos',
#  'rodou',
#  'rogos',
#  'rogou',
#  'rolos',
#  'rolou',
#  'rombo',
#  'ronco',
#  'rondo',
#  'rosno',
#  'rosto',
#  'rotos',
#  'roubo',
#  'rouco',
#  'roxos',
#  'rocou',
#  'roido',
#  'rubis',
#  'rublo',
#  'rubro',
#  'rufou',
#  'rugir',
#  'rugis',
#  'rugiu',
#  'rugou',
#  'ruido',
#  'ruimo',
#  'ruins',
#  'ruivo',
#  'rumor',
#  'rumos',
#  'rumou',
#  'russo',
#  'rocio',
#  'signo',
#  'silos',
#  'silvo',
#  'sinos',
#  'sinto',
#  'siris',
#  'sirvo',
#  'sirzo',
#  'sismo',
#  'sitio',
#  'sitos',
#  'situo',
#  'sobro',
#  'socos',
#  'socou',
#  'sofri',
#  'sofro',
#  'sogro',
#  'soldo',
#  'solos',
#  'solou',
#  'solto',
#  'somos',
#  'somou',
#  'sondo',
#  'sonho',
#  'sonos',
#  'sonso',
#  'soros',
#  'sorri',
#  'sorti',
#  'sorvi',
#  'sorvo',
#  'sovou',
#  'subir',
#  'subis',
#  'subiu',
#  'sucos',
#  'sugou',
#  'sujos',
#  'sujou',
#  'sulco',
#  'sumir',
#  'sumis',
#  'sumiu',
#  'surdo',
#  'surgi',
#  'surjo',
#  'surro',
#  'surto',
#  'susti',
#  'susto',
#  'sutil',
#  'sutis',
#  'suino',
#  'suico',
#  'simio',
#  'sirio',
#  'socio',
#  'sodio',
#  'tidos',
#  'tingi',
#  'tinir',
#  'tinis',
#  'tiniu',
#  'tinjo',
#  'tinto',
#  'tiros',
#  'tirou',
#  'titio',
#  'tocou',
#  'todos',
#  'toldo',
#  'tolhi',
#  'tolho',
#  'tolos',
#  'tombo',
#  'tomou',
#  'tonto',
#  'torci',
#  'torno',
#  'toros',
#  'torro',
#  'torto',
#  'torco',
#  'tosco',
#  'tosou',
#  'tossi',
#  'tosto',
#  'touro',
#  'tribo',
#  'trico',
#  'trigo',
#  'trino',
#  'trios',
#  'troco',
#  'trono',
#  'troto',
#  'truco',
#  'tubos',
#  'tumor',
#  'turbo',
#  'turco',
#  'turno',
#  'turvo',
#  'tusso',
#  'tutor',
#  'tibio',
#  'torio',
#  'uivos',
#  'uivou',
#  'ululo',
#  'ungir',
#  'ungis',
#  'ungiu',
#  'unido',
#  'unimo',
#  'untou',
#  'urdir',
#  'urdis',
#  'urdiu',
#  'urgir',
#  'urgis',
#  'urgiu',
#  'urino',
#  'urros',
#  'urrou',
#  'ursos',
#  'urubu',
#  'vibro',
#  'vicio',
#  'vidro',
#  'vigio',
#  'vigor',
#  'vimos',
#  'vinco',
#  'vindo',
#  'vingo',
#  'vinho',
#  'violo',
#  'viril',
#  'viris',
#  'virmo',
#  'virou',
#  'visou',
#  'visto',
#  'viuvo',
#  'vivos',
#  'volto',
#  'volvi',
#  'volvo',
#  'vosso',
#  'votos',
#  'votou',
#  'vovos',
#  'vulgo',
#  'vulto',
#  'virus',
#  'xingo',
#  'xisto',
#  'xucro',
#  'zinco',
#  'zombo',
#  'zonzo',
#  'zumbi',
#  'zumbo',
#  'zunir',
#  'zunis',
#  'zuniu',
#  'zurro',
#  'orion',
#  'idolo',
#  'indio',
#  'obito',
#  'obolo',
#  'odios',
#  'otico',
#  'otimo',
#  'ovulo',
#  'umido',
#  'unico',
#  'urico']

# %%
letra_aceita_posicao_errada = ['o',3]
lista_2 = palavra_com_letras_erradas_nas_posicoes(letra_aceita_posicao_errada, novas_palavras)

letra_aceita_posicao_errada = ['i',4]
lista_2 = palavra_com_letras_erradas_nas_posicoes(letra_aceita_posicao_errada, lista_2)

lista_2
# Out:
# ['bruno',
#  'chico',
#  'couto',
#  'filho',
#  'golfo',
#  'linus',
#  'linux',
#  'bicho',
#  'bicos',
#  'bicou',
#  'bingo',
#  'bobos',
#  'boiou',
#  'boldo',
#  'bolos',
#  'bolou',
#  'bolso',
#  'bordo',
#  'borro',
#  'botou',
#  'brigo',
#  'brins',
#  'brios',
#  'brito',
#  'bruto',
#  'bruxo',
#  'bucho',
#  'bufou',
#  'bulbo',
#  'bumbo',
#  'bundo',
#  'burgo',
#  'burlo',
#  'burro',
#  'busco',
#  'busto',
#  'buxos',
#  'bonus',
#  'chiou',
#  'chuto',
#  'ciclo',
#  'cifro',
#  'cinco',
#  'cindi',
#  'cindo',
#  'cingi',
#  'cinjo',
#  'cinto',
#  'circo',
#  'cisco',
#  'cismo',
#  'citou',
#  'cobri',
#  'cobro',
#  'cocho',
#  'cocos',
#  'coibi',
#  'coito',
#  'colhi',
#  'colho',
#  'colou',
#  'comum',
#  'conto',
#  'corno',
#  'coros',
#  'corou',
#  'corri',
#  'corro',
#  'corto',
#  'corvo',
#  'coroo',
#  'cosmo',
#  'cotou',
#  'couro',
#  'coxos',
#  'cocou',
#  'coibo',
#  'crido',
#  'criou',
#  'crivo',
#  'cruzo',
#  'cubos',
#  'cubro',
#  'cucos',
#  'cuido',
#  'cujos',
#  'cujus',
#  'culto',
#  'cunho',
#  'curou',
#  'curso',
#  'curti',
#  'curto',
#  'curvo',
#  'custo',
#  'colon',
#  'digno',
#  'dilui',
#  'diluo',
#  'disco',
#  'disso',
#  'disto',
#  'ditos',
#  'ditou',
#  'dobro',
#  'doido',
#  'domou',
#  'donos',
#  'dormi',
#  'dorso',
#  'dosou',
#  'dotou',
#  'douro',
#  'douto',
#  'dublo',
#  'durmo',
#  'duros',
#  'durou',
#  'dutos',
#  'ficho',
#  'ficou',
#  'figos',
#  'filmo',
#  'filou',
#  'finco',
#  'findo',
#  'fingi',
#  'finjo',
#  'finos',
#  'finto',
#  'firmo',
#  'fisco',
#  'fisgo',
#  'fitou',
#  'fixos',
#  'fixou',
#  'fluxo',
#  'focos',
#  'focou',
#  'fofos',
#  'fogos',
#  'folgo',
#  'fomos',
#  'forjo',
#  'formo',
#  'forno',
#  'foros',
#  'forro',
#  'forco',
#  'fosco',
#  'fosso',
#  'fotos',
#  'frigi',
#  'frijo',
#  'frios',
#  'friso',
#  'frito',
#  'fruto',
#  'fulgi',
#  'fumou',
#  'fundi',
#  'fundo',
#  'fungo',
#  'furor',
#  'furos',
#  'furou',
#  'furto',
#  'fusco',
#  'fusos',
#  'fucou',
#  'forum',
#  'gingo',
#  'giros',
#  'girou',
#  'gomos',
#  'gongo',
#  'gonzo',
#  'gordo',
#  'gorou',
#  'gorro',
#  'gosto',
#  'gozos',
#  'gozou',
#  'grifo',
#  'grilo',
#  'grito',
#  'grudo',
#  'guiou',
#  'guizo',
#  'godos',
#  'hindu',
#  'hinos',
#  'honro',
#  'horto',
#  'humor',
#  'hunos',
#  'humus',
#  'ilhou',
#  'iludi',
#  'iludo',
#  'imito',
#  'incho',
#  'incoo',
#  'induz',
#  'inflo',
#  'inibi',
#  'inibo',
#  'insto',
#  'intui',
#  'intuo',
#  'irmos',
#  'istmo',
#  'jogos',
#  'jogou',
#  'jorro',
#  'julgo',
#  'julho',
#  'junco',
#  'junho',
#  'junto',
#  'juros',
#  'jurou',
#  'justo',
#  'juizo',
#  'licor',
#  'lidos',
#  'lidou',
#  'ligou',
#  'limbo',
#  'limou',
#  'lindo',
#  'linho',
#  'lisos',
#  'listo',
#  'litro',
#  'livro',
#  'lixou',
#  'lobos',
#  'locou',
#  'logro',
#  'loiro',
#  'lombo',
#  'longo',
#  'lotou',
#  'louco',
#  'louro',
#  'louvo',
#  'lucro',
#  'lusos',
#  'lutou',
#  'luxos',
#  'lotus',
#  'micos',
#  'micro',
#  'migro',
#  'mijou',
#  'milho',
#  'mimos',
#  'mimou',
#  'minou',
#  'minto',
#  'mirou',
#  'misto',
#  'mitos',
#  'mixos',
#  'mixto',
#  'miudo',
#  'modos',
#  'mofou',
#  'mogno',
#  'mogol',
#  'moldo',
#  'molho',
#  'momos',
#  'monto',
#  'mordi',
#  'mordo',
#  'morno',
#  'morou',
#  'morri',
#  'morro',
#  'morto',
#  'motor',
#  'motos',
#  'mouro',
#  'mocos',
#  'moido',
#  'mucos',
#  'mudos',
#  'mudou',
#  'muito',
#  'multi',
#  'multo',
#  'mundo',
#  'muros',
#  'murou',
#  'murro',
#  'musco',
#  'musgo',
#  'mutuo',
#  'nicho',
#  'ninho',
#  'ninou',
#  'nisso',
#  'nisto',
#  'nitro',
#  'noivo',
#  'nosso',
#  'notou',
#  'novos',
#  'nulos',
#  'nutri',
#  'nutro',
#  'obsto',
#  'odiou',
#  'olhos',
#  'olhou',
#  'ombro',
#  'omiti',
#  'omito',
#  'orlou',
#  'ornou',
#  'orcou',
#  'ossos',
#  'ouros',
#  'ousou',
#  'outro',
#  'ovino',
#  'oxido',
#  'quilo',
#  'quito',
#  'ricos',
#  'rifou',
#  'rigor',
#  'rijos',
#  'rimos',
#  'rimou',
#  'rindo',
#  'rirmo',
#  'risco',
#  'risos',
#  'ritmo',
#  'ritos',
#  'robos',
#  'rodos',
#  'rodou',
#  'rogos',
#  'rogou',
#  'rolos',
#  'rolou',
#  'rombo',
#  'ronco',
#  'rondo',
#  'rosno',
#  'rosto',
#  'rotos',
#  'roubo',
#  'rouco',
#  'roxos',
#  'rocou',
#  'roido',
#  'rublo',
#  'rubro',
#  'rufou',
#  'rugou',
#  'ruido',
#  'ruimo',
#  'ruins',
#  'ruivo',
#  'rumor',
#  'rumos',
#  'rumou',
#  'russo',
#  'signo',
#  'silos',
#  'silvo',
#  'sinos',
#  'sinto',
#  'sirvo',
#  'sirzo',
#  'sismo',
#  'sitos',
#  'situo',
#  'sobro',
#  'socos',
#  'socou',
#  'sofri',
#  'sofro',
#  'sogro',
#  'soldo',
#  'solos',
#  'solou',
#  'solto',
#  'somos',
#  'somou',
#  'sondo',
#  'sonho',
#  'sonos',
#  'sonso',
#  'soros',
#  'sorri',
#  'sorti',
#  'sorvi',
#  'sorvo',
#  'sovou',
#  'sucos',
#  'sugou',
#  'sujos',
#  'sujou',
#  'sulco',
#  'surdo',
#  'surgi',
#  'surjo',
#  'surro',
#  'surto',
#  'susti',
#  'susto',
#  'suino',
#  'suico',
#  'tidos',
#  'tingi',
#  'tinjo',
#  'tinto',
#  'tiros',
#  'tirou',
#  'tocou',
#  'todos',
#  'toldo',
#  'tolhi',
#  'tolho',
#  'tolos',
#  'tombo',
#  'tomou',
#  'tonto',
#  'torci',
#  'torno',
#  'toros',
#  'torro',
#  'torto',
#  'torco',
#  'tosco',
#  'tosou',
#  'tossi',
#  'tosto',
#  'touro',
#  'tribo',
#  'trico',
#  'trigo',
#  'trino',
#  'trios',
#  'truco',
#  'tubos',
#  'tumor',
#  'turbo',
#  'turco',
#  'turno',
#  'turvo',
#  'tusso',
#  'tutor',
#  'uivos',
#  'uivou',
#  'ululo',
#  'unido',
#  'unimo',
#  'untou',
#  'urino',
#  'urros',
#  'urrou',
#  'ursos',
#  'urubu',
#  'vibro',
#  'vidro',
#  'vigor',
#  'vimos',
#  'vinco',
#  'vindo',
#  'vingo',
#  'vinho',
#  'virmo',
#  'virou',
#  'visou',
#  'visto',
#  'viuvo',
#  'vivos',
#  'volto',
#  'volvi',
#  'volvo',
#  'vosso',
#  'votos',
#  'votou',
#  'vovos',
#  'vulgo',
#  'vulto',
#  'virus',
#  'xingo',
#  'xisto',
#  'xucro',
#  'zinco',
#  'zombo',
#  'zonzo',
#  'zumbi',
#  'zumbo',
#  'zurro',
#  'orion',
#  'obito',
#  'odios',
#  'otico',
#  'otimo',
#  'ovulo',
#  'umido',
#  'unico',
#  'urico']

# %%
sorteia_palavra(lista_2)
# Out:
# 'ligou'

# %%
letras_n_existentes = 'd'
novas_letras_aceitas = ['o',5]

lista_2 = lista_de_palavras_possiveis(letras_local_errado, letras_n_existentes, lista_2)
#lista_2 = palavras_com_letras_nas_posicoes(novas_letras_aceitas, lista_2)
lista_2
# Out:
# ['bruno',
#  'chico',
#  'couto',
#  'filho',
#  'golfo',
#  'linus',
#  'linux',
#  'bicho',
#  'bicos',
#  'bicou',
#  'bingo',
#  'bobos',
#  'boiou',
#  'bolos',
#  'bolou',
#  'bolso',
#  'borro',
#  'botou',
#  'brigo',
#  'brins',
#  'brios',
#  'brito',
#  'bruto',
#  'bruxo',
#  'bucho',
#  'bufou',
#  'bulbo',
#  'bumbo',
#  'burgo',
#  'burlo',
#  'burro',
#  'busco',
#  'busto',
#  'buxos',
#  'bonus',
#  'chiou',
#  'chuto',
#  'ciclo',
#  'cifro',
#  'cinco',
#  'cingi',
#  'cinjo',
#  'cinto',
#  'circo',
#  'cisco',
#  'cismo',
#  'citou',
#  'cobri',
#  'cobro',
#  'cocho',
#  'cocos',
#  'coibi',
#  'coito',
#  'colhi',
#  'colho',
#  'colou',
#  'comum',
#  'conto',
#  'corno',
#  'coros',
#  'corou',
#  'corri',
#  'corro',
#  'corto',
#  'corvo',
#  'coroo',
#  'cosmo',
#  'cotou',
#  'couro',
#  'coxos',
#  'cocou',
#  'coibo',
#  'criou',
#  'crivo',
#  'cruzo',
#  'cubos',
#  'cubro',
#  'cucos',
#  'cujos',
#  'cujus',
#  'culto',
#  'cunho',
#  'curou',
#  'curso',
#  'curti',
#  'curto',
#  'curvo',
#  'custo',
#  'colon',
#  'ficho',
#  'ficou',
#  'figos',
#  'filmo',
#  'filou',
#  'finco',
#  'fingi',
#  'finjo',
#  'finos',
#  'finto',
#  'firmo',
#  'fisco',
#  'fisgo',
#  'fitou',
#  'fixos',
#  'fixou',
#  'fluxo',
#  'focos',
#  'focou',
#  'fofos',
#  'fogos',
#  'folgo',
#  'fomos',
#  'forjo',
#  'formo',
#  'forno',
#  'foros',
#  'forro',
#  'forco',
#  'fosco',
#  'fosso',
#  'fotos',
#  'frigi',
#  'frijo',
#  'frios',
#  'friso',
#  'frito',
#  'fruto',
#  'fulgi',
#  'fumou',
#  'fungo',
#  'furor',
#  'furos',
#  'furou',
#  'furto',
#  'fusco',
#  'fusos',
#  'fucou',
#  'forum',
#  'gingo',
#  'giros',
#  'girou',
#  'gomos',
#  'gongo',
#  'gonzo',
#  'gorou',
#  'gorro',
#  'gosto',
#  'gozos',
#  'gozou',
#  'grifo',
#  'grilo',
#  'grito',
#  'guiou',
#  'guizo',
#  'hinos',
#  'honro',
#  'horto',
#  'humor',
#  'hunos',
#  'humus',
#  'ilhou',
#  'imito',
#  'incho',
#  'incoo',
#  'inflo',
#  'inibi',
#  'inibo',
#  'insto',
#  'intui',
#  'intuo',
#  'irmos',
#  'istmo',
#  'jogos',
#  'jogou',
#  'jorro',
#  'julgo',
#  'julho',
#  'junco',
#  'junho',
#  'junto',
#  'juros',
#  'jurou',
#  'justo',
#  'juizo',
#  'licor',
#  'ligou',
#  'limbo',
#  'limou',
#  'linho',
#  'lisos',
#  'listo',
#  'litro',
#  'livro',
#  'lixou',
#  'lobos',
#  'locou',
#  'logro',
#  'loiro',
#  'lombo',
#  'longo',
#  'lotou',
#  'louco',
#  'louro',
#  'louvo',
#  'lucro',
#  'lusos',
#  'lutou',
#  'luxos',
#  'lotus',
#  'micos',
#  'micro',
#  'migro',
#  'mijou',
#  'milho',
#  'mimos',
#  'mimou',
#  'minou',
#  'minto',
#  'mirou',
#  'misto',
#  'mitos',
#  'mixos',
#  'mixto',
#  'mofou',
#  'mogno',
#  'mogol',
#  'molho',
#  'momos',
#  'monto',
#  'morno',
#  'morou',
#  'morri',
#  'morro',
#  'morto',
#  'motor',
#  'motos',
#  'mouro',
#  'mocos',
#  'mucos',
#  'muito',
#  'multi',
#  'multo',
#  'muros',
#  'murou',
#  'murro',
#  'musco',
#  'musgo',
#  'mutuo',
#  'nicho',
#  'ninho',
#  'ninou',
#  'nisso',
#  'nisto',
#  'nitro',
#  'noivo',
#  'nosso',
#  'notou',
#  'novos',
#  'nulos',
#  'nutri',
#  'nutro',
#  'obsto',
#  'olhos',
#  'olhou',
#  'ombro',
#  'omiti',
#  'omito',
#  'orlou',
#  'ornou',
#  'orcou',
#  'ossos',
#  'ouros',
#  'ousou',
#  'outro',
#  'ovino',
#  'quilo',
#  'quito',
#  'ricos',
#  'rifou',
#  'rigor',
#  'rijos',
#  'rimos',
#  'rimou',
#  'rirmo',
#  'risco',
#  'risos',
#  'ritmo',
#  'ritos',
#  'robos',
#  'rogos',
#  'rogou',
#  'rolos',
#  'rolou',
#  'rombo',
#  'ronco',
#  'rosno',
#  'rosto',
#  'rotos',
#  'roubo',
#  'rouco',
#  'roxos',
#  'rocou',
#  'rublo',
#  'rubro',
#  'rufou',
#  'rugou',
#  'ruimo',
#  'ruins',
#  'ruivo',
#  'rumor',
#  'rumos',
#  'rumou',
#  'russo',
#  'signo',
#  'silos',
#  'silvo',
#  'sinos',
#  'sinto',
#  'sirvo',
#  'sirzo',
#  'sismo',
#  'sitos',
#  'situo',
#  'sobro',
#  'socos',
#  'socou',
#  'sofri',
#  'sofro',
#  'sogro',
#  'solos',
#  'solou',
#  'solto',
#  'somos',
#  'somou',
#  'sonho',
#  'sonos',
#  'sonso',
#  'soros',
#  'sorri',
#  'sorti',
#  'sorvi',
#  'sorvo',
#  'sovou',
#  'sucos',
#  'sugou',
#  'sujos',
#  'sujou',
#  'sulco',
#  'surgi',
#  'surjo',
#  'surro',
#  'surto',
#  'susti',
#  'susto',
#  'suino',
#  'suico',
#  'tingi',
#  'tinjo',
#  'tinto',
#  'tiros',
#  'tirou',
#  'tocou',
#  'tolhi',
#  'tolho',
#  'tolos',
#  'tombo',
#  'tomou',
#  'tonto',
#  'torci',
#  'torno',
#  'toros',
#  'torro',
#  'torto',
#  'torco',
#  'tosco',
#  'tosou',
#  'tossi',
#  'tosto',
#  'touro',
#  'tribo',
#  'trico',
#  'trigo',
#  'trino',
#  'trios',
#  'truco',
#  'tubos',
#  'tumor',
#  'turbo',
#  'turco',
#  'turno',
#  'turvo',
#  'tusso',
#  'tutor',
#  'uivos',
#  'uivou',
#  'ululo',
#  'unimo',
#  'untou',
#  'urino',
#  'urros',
#  'urrou',
#  'ursos',
#  'urubu',
#  'vibro',
#  'vigor',
#  'vimos',
#  'vinco',
#  'vingo',
#  'vinho',
#  'virmo',
#  'virou',
#  'visou',
#  'visto',
#  'viuvo',
#  'vivos',
#  'volto',
#  'volvi',
#  'volvo',
#  'vosso',
#  'votos',
#  'votou',
#  'vovos',
#  'vulgo',
#  'vulto',
#  'virus',
#  'xingo',
#  'xisto',
#  'xucro',
#  'zinco',
#  'zombo',
#  'zonzo',
#  'zumbi',
#  'zumbo',
#  'zurro',
#  'orion',
#  'obito',
#  'otico',
#  'otimo',
#  'ovulo',
#  'unico',
#  'urico']

# %%
letra_aceita_posicao_errada = ['i',3]
lista_2 = palavra_com_letras_erradas_nas_posicoes(letra_aceita_posicao_errada, lista_2)
lista_2
# Out:
# ['bruno',
#  'couto',
#  'filho',
#  'golfo',
#  'linus',
#  'linux',
#  'bicho',
#  'bicos',
#  'bicou',
#  'bingo',
#  'bobos',
#  'bolos',
#  'bolou',
#  'bolso',
#  'borro',
#  'botou',
#  'bruto',
#  'bruxo',
#  'bucho',
#  'bufou',
#  'bulbo',
#  'bumbo',
#  'burgo',
#  'burlo',
#  'burro',
#  'busco',
#  'busto',
#  'buxos',
#  'bonus',
#  'chuto',
#  'ciclo',
#  'cifro',
#  'cinco',
#  'cingi',
#  'cinjo',
#  'cinto',
#  'circo',
#  'cisco',
#  'cismo',
#  'citou',
#  'cobri',
#  'cobro',
#  'cocho',
#  'cocos',
#  'colhi',
#  'colho',
#  'colou',
#  'comum',
#  'conto',
#  'corno',
#  'coros',
#  'corou',
#  'corri',
#  'corro',
#  'corto',
#  'corvo',
#  'coroo',
#  'cosmo',
#  'cotou',
#  'couro',
#  'coxos',
#  'cocou',
#  'cruzo',
#  'cubos',
#  'cubro',
#  'cucos',
#  'cujos',
#  'cujus',
#  'culto',
#  'cunho',
#  'curou',
#  'curso',
#  'curti',
#  'curto',
#  'curvo',
#  'custo',
#  'colon',
#  'ficho',
#  'ficou',
#  'figos',
#  'filmo',
#  'filou',
#  'finco',
#  'fingi',
#  'finjo',
#  'finos',
#  'finto',
#  'firmo',
#  'fisco',
#  'fisgo',
#  'fitou',
#  'fixos',
#  'fixou',
#  'fluxo',
#  'focos',
#  'focou',
#  'fofos',
#  'fogos',
#  'folgo',
#  'fomos',
#  'forjo',
#  'formo',
#  'forno',
#  'foros',
#  'forro',
#  'forco',
#  'fosco',
#  'fosso',
#  'fotos',
#  'fruto',
#  'fulgi',
#  'fumou',
#  'fungo',
#  'furor',
#  'furos',
#  'furou',
#  'furto',
#  'fusco',
#  'fusos',
#  'fucou',
#  'forum',
#  'gingo',
#  'giros',
#  'girou',
#  'gomos',
#  'gongo',
#  'gonzo',
#  'gorou',
#  'gorro',
#  'gosto',
#  'gozos',
#  'gozou',
#  'hinos',
#  'honro',
#  'horto',
#  'humor',
#  'hunos',
#  'humus',
#  'ilhou',
#  'incho',
#  'incoo',
#  'inflo',
#  'insto',
#  'intui',
#  'intuo',
#  'irmos',
#  'istmo',
#  'jogos',
#  'jogou',
#  'jorro',
#  'julgo',
#  'julho',
#  'junco',
#  'junho',
#  'junto',
#  'juros',
#  'jurou',
#  'justo',
#  'licor',
#  'ligou',
#  'limbo',
#  'limou',
#  'linho',
#  'lisos',
#  'listo',
#  'litro',
#  'livro',
#  'lixou',
#  'lobos',
#  'locou',
#  'logro',
#  'lombo',
#  'longo',
#  'lotou',
#  'louco',
#  'louro',
#  'louvo',
#  'lucro',
#  'lusos',
#  'lutou',
#  'luxos',
#  'lotus',
#  'micos',
#  'micro',
#  'migro',
#  'mijou',
#  'milho',
#  'mimos',
#  'mimou',
#  'minou',
#  'minto',
#  'mirou',
#  'misto',
#  'mitos',
#  'mixos',
#  'mixto',
#  'mofou',
#  'mogno',
#  'mogol',
#  'molho',
#  'momos',
#  'monto',
#  'morno',
#  'morou',
#  'morri',
#  'morro',
#  'morto',
#  'motor',
#  'motos',
#  'mouro',
#  'mocos',
#  'mucos',
#  'multi',
#  'multo',
#  'muros',
#  'murou',
#  'murro',
#  'musco',
#  'musgo',
#  'mutuo',
#  'nicho',
#  'ninho',
#  'ninou',
#  'nisso',
#  'nisto',
#  'nitro',
#  'nosso',
#  'notou',
#  'novos',
#  'nulos',
#  'nutri',
#  'nutro',
#  'obsto',
#  'olhos',
#  'olhou',
#  'ombro',
#  'orlou',
#  'ornou',
#  'orcou',
#  'ossos',
#  'ouros',
#  'ousou',
#  'outro',
#  'ricos',
#  'rifou',
#  'rigor',
#  'rijos',
#  'rimos',
#  'rimou',
#  'rirmo',
#  'risco',
#  'risos',
#  'ritmo',
#  'ritos',
#  'robos',
#  'rogos',
#  'rogou',
#  'rolos',
#  'rolou',
#  'rombo',
#  'ronco',
#  'rosno',
#  'rosto',
#  'rotos',
#  'roubo',
#  'rouco',
#  'roxos',
#  'rocou',
#  'rublo',
#  'rubro',
#  'rufou',
#  'rugou',
#  'rumor',
#  'rumos',
#  'rumou',
#  'russo',
#  'signo',
#  'silos',
#  'silvo',
#  'sinos',
#  'sinto',
#  'sirvo',
#  'sirzo',
#  'sismo',
#  'sitos',
#  'situo',
#  'sobro',
#  'socos',
#  'socou',
#  'sofri',
#  'sofro',
#  'sogro',
#  'solos',
#  'solou',
#  'solto',
#  'somos',
#  'somou',
#  'sonho',
#  'sonos',
#  'sonso',
#  'soros',
#  'sorri',
#  'sorti',
#  'sorvi',
#  'sorvo',
#  'sovou',
#  'sucos',
#  'sugou',
#  'sujos',
#  'sujou',
#  'sulco',
#  'surgi',
#  'surjo',
#  'surro',
#  'surto',
#  'susti',
#  'susto',
#  'tingi',
#  'tinjo',
#  'tinto',
#  'tiros',
#  'tirou',
#  'tocou',
#  'tolhi',
#  'tolho',
#  'tolos',
#  'tombo',
#  'tomou',
#  'tonto',
#  'torci',
#  'torno',
#  'toros',
#  'torro',
#  'torto',
#  'torco',
#  'tosco',
#  'tosou',
#  'tossi',
#  'tosto',
#  'touro',
#  'truco',
#  'tubos',
#  'tumor',
#  'turbo',
#  'turco',
#  'turno',
#  'turvo',
#  'tusso',
#  'tutor',
#  'uivos',
#  'uivou',
#  'ululo',
#  'untou',
#  'urros',
#  'urrou',
#  'ursos',
#  'urubu',
#  'vibro',
#  'vigor',
#  'vimos',
#  'vinco',
#  'vingo',
#  'vinho',
#  'virmo',
#  'virou',
#  'visou',
#  'visto',
#  'viuvo',
#  'vivos',
#  'volto',
#  'volvi',
#  'volvo',
#  'vosso',
#  'votos',
#  'votou',
#  'vovos',
#  'vulgo',
#  'vulto',
#  'virus',
#  'xingo',
#  'xisto',
#  'xucro',
#  'zinco',
#  'zombo',
#  'zonzo',
#  'zumbi',
#  'zumbo',
#  'zurro',
#  'ovulo']

# %%
letra_aceita_posicao_errada = ['i',4]
lista_2 = palavra_com_letras_erradas_nas_posicoes(letra_aceita_posicao_errada, lista_2)
lista_2
# Out:
# ['bruno',
#  'couto',
#  'filho',
#  'golfo',
#  'linus',
#  'linux',
#  'bicho',
#  'bicos',
#  'bicou',
#  'bingo',
#  'bobos',
#  'bolos',
#  'bolou',
#  'bolso',
#  'borro',
#  'botou',
#  'bruto',
#  'bruxo',
#  'bucho',
#  'bufou',
#  'bulbo',
#  'bumbo',
#  'burgo',
#  'burlo',
#  'burro',
#  'busco',
#  'busto',
#  'buxos',
#  'bonus',
#  'chuto',
#  'ciclo',
#  'cifro',
#  'cinco',
#  'cingi',
#  'cinjo',
#  'cinto',
#  'circo',
#  'cisco',
#  'cismo',
#  'citou',
#  'cobri',
#  'cobro',
#  'cocho',
#  'cocos',
#  'colhi',
#  'colho',
#  'colou',
#  'comum',
#  'conto',
#  'corno',
#  'coros',
#  'corou',
#  'corri',
#  'corro',
#  'corto',
#  'corvo',
#  'coroo',
#  'cosmo',
#  'cotou',
#  'couro',
#  'coxos',
#  'cocou',
#  'cruzo',
#  'cubos',
#  'cubro',
#  'cucos',
#  'cujos',
#  'cujus',
#  'culto',
#  'cunho',
#  'curou',
#  'curso',
#  'curti',
#  'curto',
#  'curvo',
#  'custo',
#  'colon',
#  'ficho',
#  'ficou',
#  'figos',
#  'filmo',
#  'filou',
#  'finco',
#  'fingi',
#  'finjo',
#  'finos',
#  'finto',
#  'firmo',
#  'fisco',
#  'fisgo',
#  'fitou',
#  'fixos',
#  'fixou',
#  'fluxo',
#  'focos',
#  'focou',
#  'fofos',
#  'fogos',
#  'folgo',
#  'fomos',
#  'forjo',
#  'formo',
#  'forno',
#  'foros',
#  'forro',
#  'forco',
#  'fosco',
#  'fosso',
#  'fotos',
#  'fruto',
#  'fulgi',
#  'fumou',
#  'fungo',
#  'furor',
#  'furos',
#  'furou',
#  'furto',
#  'fusco',
#  'fusos',
#  'fucou',
#  'forum',
#  'gingo',
#  'giros',
#  'girou',
#  'gomos',
#  'gongo',
#  'gonzo',
#  'gorou',
#  'gorro',
#  'gosto',
#  'gozos',
#  'gozou',
#  'hinos',
#  'honro',
#  'horto',
#  'humor',
#  'hunos',
#  'humus',
#  'ilhou',
#  'incho',
#  'incoo',
#  'inflo',
#  'insto',
#  'intui',
#  'intuo',
#  'irmos',
#  'istmo',
#  'jogos',
#  'jogou',
#  'jorro',
#  'julgo',
#  'julho',
#  'junco',
#  'junho',
#  'junto',
#  'juros',
#  'jurou',
#  'justo',
#  'licor',
#  'ligou',
#  'limbo',
#  'limou',
#  'linho',
#  'lisos',
#  'listo',
#  'litro',
#  'livro',
#  'lixou',
#  'lobos',
#  'locou',
#  'logro',
#  'lombo',
#  'longo',
#  'lotou',
#  'louco',
#  'louro',
#  'louvo',
#  'lucro',
#  'lusos',
#  'lutou',
#  'luxos',
#  'lotus',
#  'micos',
#  'micro',
#  'migro',
#  'mijou',
#  'milho',
#  'mimos',
#  'mimou',
#  'minou',
#  'minto',
#  'mirou',
#  'misto',
#  'mitos',
#  'mixos',
#  'mixto',
#  'mofou',
#  'mogno',
#  'mogol',
#  'molho',
#  'momos',
#  'monto',
#  'morno',
#  'morou',
#  'morri',
#  'morro',
#  'morto',
#  'motor',
#  'motos',
#  'mouro',
#  'mocos',
#  'mucos',
#  'multi',
#  'multo',
#  'muros',
#  'murou',
#  'murro',
#  'musco',
#  'musgo',
#  'mutuo',
#  'nicho',
#  'ninho',
#  'ninou',
#  'nisso',
#  'nisto',
#  'nitro',
#  'nosso',
#  'notou',
#  'novos',
#  'nulos',
#  'nutri',
#  'nutro',
#  'obsto',
#  'olhos',
#  'olhou',
#  'ombro',
#  'orlou',
#  'ornou',
#  'orcou',
#  'ossos',
#  'ouros',
#  'ousou',
#  'outro',
#  'ricos',
#  'rifou',
#  'rigor',
#  'rijos',
#  'rimos',
#  'rimou',
#  'rirmo',
#  'risco',
#  'risos',
#  'ritmo',
#  'ritos',
#  'robos',
#  'rogos',
#  'rogou',
#  'rolos',
#  'rolou',
#  'rombo',
#  'ronco',
#  'rosno',
#  'rosto',
#  'rotos',
#  'roubo',
#  'rouco',
#  'roxos',
#  'rocou',
#  'rublo',
#  'rubro',
#  'rufou',
#  'rugou',
#  'rumor',
#  'rumos',
#  'rumou',
#  'russo',
#  'signo',
#  'silos',
#  'silvo',
#  'sinos',
#  'sinto',
#  'sirvo',
#  'sirzo',
#  'sismo',
#  'sitos',
#  'situo',
#  'sobro',
#  'socos',
#  'socou',
#  'sofri',
#  'sofro',
#  'sogro',
#  'solos',
#  'solou',
#  'solto',
#  'somos',
#  'somou',
#  'sonho',
#  'sonos',
#  'sonso',
#  'soros',
#  'sorri',
#  'sorti',
#  'sorvi',
#  'sorvo',
#  'sovou',
#  'sucos',
#  'sugou',
#  'sujos',
#  'sujou',
#  'sulco',
#  'surgi',
#  'surjo',
#  'surro',
#  'surto',
#  'susti',
#  'susto',
#  'tingi',
#  'tinjo',
#  'tinto',
#  'tiros',
#  'tirou',
#  'tocou',
#  'tolhi',
#  'tolho',
#  'tolos',
#  'tombo',
#  'tomou',
#  'tonto',
#  'torci',
#  'torno',
#  'toros',
#  'torro',
#  'torto',
#  'torco',
#  'tosco',
#  'tosou',
#  'tossi',
#  'tosto',
#  'touro',
#  'truco',
#  'tubos',
#  'tumor',
#  'turbo',
#  'turco',
#  'turno',
#  'turvo',
#  'tusso',
#  'tutor',
#  'uivos',
#  'uivou',
#  'ululo',
#  'untou',
#  'urros',
#  'urrou',
#  'ursos',
#  'urubu',
#  'vibro',
#  'vigor',
#  'vimos',
#  'vinco',
#  'vingo',
#  'vinho',
#  'virmo',
#  'virou',
#  'visou',
#  'visto',
#  'viuvo',
#  'vivos',
#  'volto',
#  'volvi',
#  'volvo',
#  'vosso',
#  'votos',
#  'votou',
#  'vovos',
#  'vulgo',
#  'vulto',
#  'virus',
#  'xingo',
#  'xisto',
#  'xucro',
#  'zinco',
#  'zombo',
#  'zonzo',
#  'zumbi',
#  'zumbo',
#  'zurro',
#  'ovulo']

# %%
letra_aceita_posicao_errada = ['o',2]
lista_2 = palavra_com_letras_erradas_nas_posicoes(letra_aceita_posicao_errada, lista_2)
lista_2
# Out:
# ['bruno',
#  'filho',
#  'linus',
#  'linux',
#  'bicho',
#  'bicos',
#  'bicou',
#  'bingo',
#  'bruto',
#  'bruxo',
#  'bucho',
#  'bufou',
#  'bulbo',
#  'bumbo',
#  'burgo',
#  'burlo',
#  'burro',
#  'busco',
#  'busto',
#  'buxos',
#  'chuto',
#  'ciclo',
#  'cifro',
#  'cinco',
#  'cingi',
#  'cinjo',
#  'cinto',
#  'circo',
#  'cisco',
#  'cismo',
#  'citou',
#  'cruzo',
#  'cubos',
#  'cubro',
#  'cucos',
#  'cujos',
#  'cujus',
#  'culto',
#  'cunho',
#  'curou',
#  'curso',
#  'curti',
#  'curto',
#  'curvo',
#  'custo',
#  'ficho',
#  'ficou',
#  'figos',
#  'filmo',
#  'filou',
#  'finco',
#  'fingi',
#  'finjo',
#  'finos',
#  'finto',
#  'firmo',
#  'fisco',
#  'fisgo',
#  'fitou',
#  'fixos',
#  'fixou',
#  'fluxo',
#  'fruto',
#  'fulgi',
#  'fumou',
#  'fungo',
#  'furor',
#  'furos',
#  'furou',
#  'furto',
#  'fusco',
#  'fusos',
#  'fucou',
#  'gingo',
#  'giros',
#  'girou',
#  'hinos',
#  'humor',
#  'hunos',
#  'humus',
#  'ilhou',
#  'incho',
#  'incoo',
#  'inflo',
#  'insto',
#  'intui',
#  'intuo',
#  'irmos',
#  'istmo',
#  'julgo',
#  'julho',
#  'junco',
#  'junho',
#  'junto',
#  'juros',
#  'jurou',
#  'justo',
#  'licor',
#  'ligou',
#  'limbo',
#  'limou',
#  'linho',
#  'lisos',
#  'listo',
#  'litro',
#  'livro',
#  'lixou',
#  'lucro',
#  'lusos',
#  'lutou',
#  'luxos',
#  'micos',
#  'micro',
#  'migro',
#  'mijou',
#  'milho',
#  'mimos',
#  'mimou',
#  'minou',
#  'minto',
#  'mirou',
#  'misto',
#  'mitos',
#  'mixos',
#  'mixto',
#  'mucos',
#  'multi',
#  'multo',
#  'muros',
#  'murou',
#  'murro',
#  'musco',
#  'musgo',
#  'mutuo',
#  'nicho',
#  'ninho',
#  'ninou',
#  'nisso',
#  'nisto',
#  'nitro',
#  'nulos',
#  'nutri',
#  'nutro',
#  'obsto',
#  'olhos',
#  'olhou',
#  'ombro',
#  'orlou',
#  'ornou',
#  'orcou',
#  'ossos',
#  'ouros',
#  'ousou',
#  'outro',
#  'ricos',
#  'rifou',
#  'rigor',
#  'rijos',
#  'rimos',
#  'rimou',
#  'rirmo',
#  'risco',
#  'risos',
#  'ritmo',
#  'ritos',
#  'rublo',
#  'rubro',
#  'rufou',
#  'rugou',
#  'rumor',
#  'rumos',
#  'rumou',
#  'russo',
#  'signo',
#  'silos',
#  'silvo',
#  'sinos',
#  'sinto',
#  'sirvo',
#  'sirzo',
#  'sismo',
#  'sitos',
#  'situo',
#  'sucos',
#  'sugou',
#  'sujos',
#  'sujou',
#  'sulco',
#  'surgi',
#  'surjo',
#  'surro',
#  'surto',
#  'susti',
#  'susto',
#  'tingi',
#  'tinjo',
#  'tinto',
#  'tiros',
#  'tirou',
#  'truco',
#  'tubos',
#  'tumor',
#  'turbo',
#  'turco',
#  'turno',
#  'turvo',
#  'tusso',
#  'tutor',
#  'uivos',
#  'uivou',
#  'ululo',
#  'untou',
#  'urros',
#  'urrou',
#  'ursos',
#  'urubu',
#  'vibro',
#  'vigor',
#  'vimos',
#  'vinco',
#  'vingo',
#  'vinho',
#  'virmo',
#  'virou',
#  'visou',
#  'visto',
#  'viuvo',
#  'vivos',
#  'vulgo',
#  'vulto',
#  'virus',
#  'xingo',
#  'xisto',
#  'xucro',
#  'zinco',
#  'zumbi',
#  'zumbo',
#  'zurro',
#  'ovulo']

# %%
novas_letras_aceitas = ['o',5]
lista_2 = palavras_com_letras_nas_posicoes(novas_letras_aceitas, lista_2)
lista_2
# Out:
# ['bruno',
#  'filho',
#  'bicho',
#  'bingo',
#  'bruto',
#  'bruxo',
#  'bucho',
#  'bulbo',
#  'bumbo',
#  'burgo',
#  'burlo',
#  'burro',
#  'busco',
#  'busto',
#  'chuto',
#  'ciclo',
#  'cifro',
#  'cinco',
#  'cinjo',
#  'cinto',
#  'circo',
#  'cisco',
#  'cismo',
#  'cruzo',
#  'cubro',
#  'culto',
#  'cunho',
#  'curso',
#  'curto',
#  'curvo',
#  'custo',
#  'ficho',
#  'filmo',
#  'finco',
#  'finjo',
#  'finto',
#  'firmo',
#  'fisco',
#  'fisgo',
#  'fluxo',
#  'fruto',
#  'fungo',
#  'furto',
#  'fusco',
#  'gingo',
#  'incho',
#  'incoo',
#  'inflo',
#  'insto',
#  'intuo',
#  'istmo',
#  'julgo',
#  'julho',
#  'junco',
#  'junho',
#  'junto',
#  'justo',
#  'limbo',
#  'linho',
#  'listo',
#  'litro',
#  'livro',
#  'lucro',
#  'micro',
#  'migro',
#  'milho',
#  'minto',
#  'misto',
#  'mixto',
#  'multo',
#  'murro',
#  'musco',
#  'musgo',
#  'mutuo',
#  'nicho',
#  'ninho',
#  'nisso',
#  'nisto',
#  'nitro',
#  'nutro',
#  'obsto',
#  'ombro',
#  'outro',
#  'rirmo',
#  'risco',
#  'ritmo',
#  'rublo',
#  'rubro',
#  'russo',
#  'signo',
#  'silvo',
#  'sinto',
#  'sirvo',
#  'sirzo',
#  'sismo',
#  'situo',
#  'sulco',
#  'surjo',
#  'surro',
#  'surto',
#  'susto',
#  'tinjo',
#  'tinto',
#  'truco',
#  'turbo',
#  'turco',
#  'turno',
#  'turvo',
#  'tusso',
#  'ululo',
#  'vibro',
#  'vinco',
#  'vingo',
#  'vinho',
#  'virmo',
#  'visto',
#  'viuvo',
#  'vulgo',
#  'vulto',
#  'xingo',
#  'xisto',
#  'xucro',
#  'zinco',
#  'zumbo',
#  'zurro',
#  'ovulo']

# %%
sorteia_palavra(lista_2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-126-251c1cab046c> in <module>
# ----> 1 sorteia_palavra(lista_2)
#
# <ipython-input-38-bf106eb1488d> in sorteia_palavra(lista_palavra)
#       1 def sorteia_palavra(lista_palavra):
# ----> 2     return lista_palavra[random.randint(0,len(lista_palavra))]
#       3
#       4 palavra_sorteada = sorteia_palavra(lista_2)
#       5 palavra_sorteada
#
# IndexError: list index out of range

# %%
letras_n_existentes = 'jun'
novas_letras_aceitas = ['t',4]

lista_2 = lista_de_palavras_possiveis(letras_local_errado, letras_n_existentes, lista_2)

lista_2
# Out:
# ['filho',
#  'bicho',
#  'ciclo',
#  'cifro',
#  'circo',
#  'cisco',
#  'cismo',
#  'ficho',
#  'filmo',
#  'firmo',
#  'fisco',
#  'fisgo',
#  'istmo',
#  'limbo',
#  'listo',
#  'litro',
#  'livro',
#  'micro',
#  'migro',
#  'milho',
#  'misto',
#  'mixto',
#  'obsto',
#  'ombro',
#  'rirmo',
#  'risco',
#  'ritmo',
#  'silvo',
#  'sirvo',
#  'sirzo',
#  'sismo',
#  'vibro',
#  'virmo',
#  'visto',
#  'xisto']

# %%
sorteia_palavra(lista_2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-128-251c1cab046c> in <module>
# ----> 1 sorteia_palavra(lista_2)
#
# <ipython-input-38-bf106eb1488d> in sorteia_palavra(lista_palavra)
#       1 def sorteia_palavra(lista_palavra):
# ----> 2     return lista_palavra[random.randint(0,len(lista_palavra))]
#       3
#       4 palavra_sorteada = sorteia_palavra(lista_2)
#       5 palavra_sorteada
#
# IndexError: list index out of range

# %%
lista_2
# Out:
# ['filho',
#  'bicho',
#  'ciclo',
#  'cifro',
#  'circo',
#  'cisco',
#  'cismo',
#  'ficho',
#  'filmo',
#  'firmo',
#  'fisco',
#  'fisgo',
#  'istmo',
#  'limbo',
#  'listo',
#  'litro',
#  'livro',
#  'micro',
#  'migro',
#  'milho',
#  'misto',
#  'mixto',
#  'obsto',
#  'ombro',
#  'rirmo',
#  'risco',
#  'ritmo',
#  'silvo',
#  'sirvo',
#  'sirzo',
#  'sismo',
#  'vibro',
#  'virmo',
#  'visto',
#  'xisto']

# %%
letras_n_existentes = 'hr'
letras_local_errado = ''

teste = lista_de_palavras_possiveis(letras_local_errado, letras_n_existentes, lista_2)
teste
# Out:
# ['ciclo',
#  'cisco',
#  'cismo',
#  'filmo',
#  'fisco',
#  'fisgo',
#  'istmo',
#  'limbo',
#  'listo',
#  'misto',
#  'mixto',
#  'obsto',
#  'silvo',
#  'sismo',
#  'visto',
#  'xisto']

# %%
novas_letras_aceitas = ['t',4]
lista_2 = palavras_com_letras_nas_posicoes(novas_letras_aceitas, lista_2)
lista_2

# %%
novas_letras_aceitas = ['i',2]
lista_2 = palavras_com_letras_nas_posicoes(novas_letras_aceitas, lista_2)

novas_letras_aceitas = ['s',3]
lista_2 = palavras_com_letras_nas_posicoes(novas_letras_aceitas, lista_2)


lista_2
# Out:
# ['listo', 'misto', 'visto', 'xisto']

# %%
letras_n_existentes = 'hr'

# %%
letras_local_errado = ''
letras_n_existentes = 'l'

lista_2 = lista_de_palavras_possiveis(letras_local_errado, letras_n_existentes, lista_2)
lista_2
# Out:
# ['misto', 'visto', 'xisto']

# %%
sorteia_palavra(lista_2)
# Out:
# 'xisto'

# %% [markdown]
# # solução de trabalhar com tabela

# %%
palavras[:5]
# Out:
# ['aarao', 'abner', 'acaia', 'acker', 'aires']

# %%
list_possible_anwer = palavras

arr_words_51 = palavras

# %%
print(arr_words_51)
# Out:
# <generator object <genexpr> at 0x00000268337FC350>

# %% [markdown]
# - mudar as nomenclaturas para 0,1,2,3,4

# %%
df_teste = df.copy()

df_teste['letra_0'] = df_teste.palavra.str[0]
df_teste['letra_1'] = df_teste.palavra.str[1]
df_teste['letra_2'] = df_teste.palavra.str[2]
df_teste['letra_3'] = df_teste.palavra.str[3]
df_teste['letra_4'] = df_teste.palavra.str[4]
df_teste.head()
# Out:
#   palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 0   aarao         4              2       a       a       r       a       o
# 1   abner         2              2       a       b       n       e       r
# 2   acaia         4              2       a       c       a       i       a
# 3   acker         2              2       a       c       k       e       r
# 4   aires         3              3       a       i       r       e       s

# %%
letras_indesejadas = 'apie'
lista = []
for i in letras_indesejadas:
    lista.append(i)
    print(i)
# Out:
# a
# p
# i
# e

# %%
mask = (df_teste.letra_1 != 'a') & (df_teste.letra_2 != 'a') & (df_teste.letra_3 != 'a') & (df_teste.letra_4 != 'a') & (df_teste.letra_5 != 'a')
df_teste.loc[mask,:]
# Out:
#      palavra letra_1 letra_2 letra_3 letra_4 letra_5
# 19     belem       b       e       l       e       m
# 20     bento       b       e       n       t       o
# 23     bielo       b       i       e       l       o
# 25     bruno       b       r       u       n       o
# 29     chico       c       h       i       c       o
# ...      ...     ...     ...     ...     ...     ...
# 6018   umido       u       m       i       d       o
# 6020   unico       u       n       i       c       o
# 6021   urico       u       r       i       c       o
# 6022   uteis       u       t       e       i       s
# 6023   utero       u       t       e       r       o
#
# [2135 rows x 6 columns]

# %%
df_corte = df_teste.copy()

for item in lista:
    mask = (df_teste.letra_1 != item) & (df_teste.letra_2 != item) & (df_teste.letra_3 != item) & (df_teste.letra_4 != item) & (df_teste.letra_5 != item)
    df_corte = df_corte.loc[mask,:]

    
df_corte.head()
# Out:
#     palavra letra_1 letra_2 letra_3 letra_4 letra_5
# 25    bruno       b       r       u       n       o
# 32    couto       c       o       u       t       o
# 57    golfo       g       o       l       f       o
# 896   bloco       b       l       o       c       o
# 902   bobos       b       o       b       o       s

# %%
df_teste.shape
# Out:
# (6024, 6)

# %%
df_corte.shape
# Out:
# (306, 6)

# %%
def letras_nao_aceitas(letras, df):
    lista = []
    
    if len(letras) > 1:
        for i in letras:
            lista.append(i)
        mask = ~df.letra_0.isin(lista) & ~df.letra_1.isin(lista) & ~df.letra_2.isin(lista) & ~df.letra_3.isin(lista) & ~df.letra_4.isin(lista)
    else:
        mask = (df.letra_0 != letras) & (df.letra_1 != letras) & (df.letra_2 != letras) & (df.letra_3 != letras) & (df.letra_4 != letras)

    return df.loc[mask,:]

# %%
df_corte = df_teste.copy()
df_corte
# Out:
#      palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 0      aarao         4              2       a       a       r       a       o
# 1      abner         2              2       a       b       n       e       r
# 2      acaia         4              2       a       c       a       i       a
# 3      acker         2              2       a       c       k       e       r
# 4      aires         3              3       a       i       r       e       s
# ...      ...       ...            ...     ...     ...     ...     ...     ...
# 6019   unica         3              3       u       n       i       c       a
# 6020   unico         3              3       u       n       i       c       o
# 6021   urico         3              3       u       r       i       c       o
# 6022   uteis         3              3       u       t       e       i       s
# 6023   utero         3              3       u       t       e       r       o
#
# [5425 rows x 8 columns]

# %%
item
# Out:
# 'a'

# %%
df_corte = df_teste.copy()
lista = []
letras_indesejadas = 'apoi'
for i in letras_indesejadas:
    lista.append(i)

mask = ~df_corte.letra_1.isin(lista) & ~df_corte.letra_2.isin(lista) & ~df_corte.letra_3.isin(lista) & ~df_corte.letra_4.isin(lista) & ~df_corte.letra_5.isin(lista)
df_corte.loc[mask,:]
# Out:
#      palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 19     belem         2              1       b       e       l       e       m
# 50     ester         2              1       e       s       t       e       r
# 51     euler         3              2       e       u       l       e       r
# 58     hegel         2              1       h       e       g       e       l
# 62     jesus         2              2       j       e       s       u       s
# ...      ...       ...            ...     ...     ...     ...     ...     ...
# 5899   zeres         2              1       z       e       r       e       s
# 5911   zumbe         2              2       z       u       m       b       e
# 5916   zunem         2              2       z       u       n       e       m
# 5917   zunes         2              2       z       u       n       e       s
# 5923   zurre         2              2       z       u       r       r       e
#
# [308 rows x 8 columns]

# %%
df_corte = df_teste.copy()

letras_indesejadas = 'apoi'
lista = []

for i in letras_indesejadas:
    mask = (df_corte.letra_1 != str(item)) & (df_corte.letra_2 != str(item)) & (df_corte.letra_3 != str(item)) & (df_corte.letra_4 != str(item)) & (df_corte.letra_5 != str(item))
    df_corte = df_corte.loc[mask,:] 

df_corte
# Out:
#      palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 19     belem         2              1       b       e       l       e       m
# 20     bento         2              2       b       e       n       t       o
# 23     bielo         3              3       b       i       e       l       o
# 25     bruno         2              2       b       r       u       n       o
# 29     chico         2              2       c       h       i       c       o
# ...      ...       ...            ...     ...     ...     ...     ...     ...
# 6018   umido         3              3       u       m       i       d       o
# 6020   unico         3              3       u       n       i       c       o
# 6021   urico         3              3       u       r       i       c       o
# 6022   uteis         3              3       u       t       e       i       s
# 6023   utero         3              3       u       t       e       r       o
#
# [2064 rows x 8 columns]

# %%
letras_indesejadas = 'apoi'

df_corte = letras_nao_aceitas(letras_indesejadas, df_teste)
df_corte
# Out:
#      palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 19     belem         2              1       b       e       l       e       m
# 50     ester         2              1       e       s       t       e       r
# 51     euler         3              2       e       u       l       e       r
# 58     hegel         2              1       h       e       g       e       l
# 62     jesus         2              2       j       e       s       u       s
# ...      ...       ...            ...     ...     ...     ...     ...     ...
# 5899   zeres         2              1       z       e       r       e       s
# 5911   zumbe         2              2       z       u       m       b       e
# 5916   zunem         2              2       z       u       n       e       m
# 5917   zunes         2              2       z       u       n       e       s
# 5923   zurre         2              2       z       u       r       r       e
#
# [308 rows x 8 columns]

# %%
#verificar se a posicao esta começando em 0 ou 1!

def letra_na_posicao(posicao,letra,df):

    nome_tabela = 'letra_'+str(posicao)

    mask = df[nome_tabela] == letra
    
    return df.loc[mask,:]

# %%
posicao = 5
letra_desejada = 'e'


df_corte = letra_na_posicao(posicao,letra_desejada,df_corte)
df_corte
# Out:
#      palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 865    benze         2              1       b       e       n       z       e
# 869    beque         3              2       b       e       q       u       e
# 872    berre         2              1       b       e       r       r       e
# 893    blefe         2              1       b       l       e       f       e
# 972    breve         2              1       b       r       e       v       e
# ...      ...       ...            ...     ...     ...     ...     ...     ...
# 5691   verte         2              1       v       e       r       t       e
# 5700   veste         2              1       v       e       s       t       e
# 5862   xeque         3              2       x       e       q       u       e
# 5911   zumbe         2              2       z       u       m       b       e
# 5923   zurre         2              2       z       u       r       r       e
#
# [117 rows x 8 columns]

# %%
letras_indesejadas = 'sar'
teste = letras_nao_aceitas(letras_indesejadas, df_corte)
teste
# Out:
#      palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 865    benze         2              1       b       e       n       z       e
# 869    beque         3              2       b       e       q       u       e
# 893    blefe         2              1       b       l       e       f       e
# 1021   bunde         2              2       b       u       n       d       e
# 1239   cegue         3              2       c       e       g       u       e
# 1293   chefe         2              1       c       h       e       f       e
# 1328   chute         2              2       c       h       u       t       e
# 1386   clube         2              2       c       l       u       b       e
# 1599   cunhe         2              2       c       u       n       h       e
# 1702   dente         2              1       d       e       n       t       e
# 1860   duble         2              2       d       u       b       l       e
# 1865   duele         3              2       d       u       e       l       e
# 1874   duque         3              2       d       u       q       u       e
# 1913   ejete         3              1       e       j       e       t       e
# 1916   elege         3              1       e       l       e       g       e
# 1922   eleve         3              1       e       l       e       v       e
# 1940   emule         3              2       e       m       u       l       e
# 1944   enche         2              1       e       n       c       h       e
# 2082   exume         3              2       e       x       u       m       e
# 2155   feche         2              1       f       e       c       h       e
# 2175   fende         2              1       f       e       n       d       e
# 2425   fulge         2              2       f       u       l       g       e
# 2436   funde         2              2       f       u       n       d       e
# 2569   gente         2              1       g       e       n       t       e
# 2872   jegue         3              2       j       e       g       u       e
# 2875   jejue         3              2       j       e       j       u       e
# 2909   junte         2              2       j       u       n       t       e
# 3003   legue         3              2       l       e       g       u       e
# 3019   lente         2              1       l       e       n       t       e
# 3024   leque         3              2       l       e       q       u       e
# 3328   mente         2              1       m       e       n       t       e
# 3534   multe         2              2       m       u       l       t       e
# 3620   negue         3              2       n       e       g       u       e
# 4295   quede         3              2       q       u       e       d       e
# 5182   tecle         2              1       t       e       c       l       e
# 5207   tende         2              1       t       e       n       d       e
# 5219   tente         2              1       t       e       n       t       e
# 5464   tenue         3              2       t       e       n       u       e
# 5486   ulule         3              2       u       l       u       l       e
# 5660   vence         2              1       v       e       n       c       e
# 5664   vende         2              1       v       e       n       d       e
# 5672   vente         2              1       v       e       n       t       e
# 5862   xeque         3              2       x       e       q       u       e
# 5911   zumbe         2              2       z       u       m       b       e

# %%
letras_desejadas_fora_posicao = ['g',2]

def asaaaaaa(letras_desejadas, df):
    lista = []
    
    for i in letras_desejadas:
        lista.append(i)

        
    mask = df.letra_1.isin(lista) | df.letra_2.isin(lista) | df.letra_3.isin(lista) | df.letra_4.isin(lista) | df.letra_5.isin(lista)
    return df.loc[mask,:]

# %%
lista_de_letras_com_posicao = [['g',2]]

def palavras_com_letra_posicao_errada(lista_de_letras_com_posicao, df):   
    lista = []
    for indice1,indice2 in lista_de_letras_com_posicao:
        lista.append(indice1)
        
        condicao = indice2
        if condicao == 0:
            mask = df.letra_1.isin(lista) | df.letra_2.isin(lista) | df.letra_3.isin(lista) | df.letra_4.isin(lista)
            df = df.loc[mask,:]
        elif condicao == 1:
            mask = df.letra_0.isin(lista) | df.letra_2.isin(lista) | df.letra_3.isin(lista) | df.letra_4.isin(lista) 
            df = df.loc[mask,:]
        elif condicao == 2:
            mask = df.letra_0.isin(lista) | df.letra_1.isin(lista) | df.letra_3.isin(lista) | df.letra_4.isin(lista)
            df = df.loc[mask,:]
        elif condicao == 3:
            mask = df.letra_0.isin(lista) | df.letra_1.isin(lista) | df.letra_2.isin(lista) | df.letra_4.isin(lista)
            df = df.loc[mask,:]
        elif condicao == 4:
            mask = df.letra_0.isin(lista) | df.letra_1.isin(lista) | df.letra_2.isin(lista) | df.letra_3.isin(lista)
            df = df.loc[mask,:]

    return df

# %%
lista_de_letras_com_posicao = [['g',2]]

if len(lista_de_letras_com_posicao) > 1:
    print('lista de dentro')

for indice1, indice2 in lista_de_letras_com_posicao:
    print(indice1)
    print(indice2)
# Out:
# g
# 2

# %%
teste_2 = teste_de_funcao(lista_de_letras_com_posicao,teste)
teste_2
# Out:
#      palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 1916   elege         3              1       e       l       e       g       e
# 2425   fulge         2              2       f       u       l       g       e
# 2569   gente         2              1       g       e       n       t       e

# %%
palavra_sorteada = sorteia_palavra(teste_2.palavra.values.tolist())
palavra_sorteada
# Out:
# 'elege'

# %%
terceira_tentativa = palavra_sorteada

# %%
dicionario_lista_da_palavra_3
# Out:
# {0: ['letter place', 'E'],
#  1: ['letter wrong', 'L'],
#  2: ['letter wrong', 'E'],
#  3: ['letter place', 'G'],
#  4: ['letter right', 'E']}

# %%
teste_2
# Out:
#      palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 1916   elege         3              1       e       l       e       g       e
# 2425   fulge         2              2       f       u       l       g       e
# 2569   gente         2              1       g       e       n       t       e

# %%
lista_de_letras_com_posicao = [['g',3]]
letras_indesejadas = 'l'

teste_3 = letras_nao_aceitas(letras_indesejadas, teste_2)
teste_3
# Out:
#      palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 2569   gente         2              1       g       e       n       t       e

# %%
teste_3 = palavras_com_letra_posicao_errada(lista_de_letras_com_posicao,teste_3)
teste_3

# %%
segunda_tentativa = sorteia_palavra(df_corte.palavra.values.tolist())
print(segunda_tentativa)
# Out:
# sagre

# %%
teste_3
# Out:
#      palavra  n_vogais  vogais_unicas letra_1 letra_2 letra_3 letra_4 letra_5
# 2569   gente         2              1       g       e       n       t       e

# %%
print(sorteia_palavra(teste_3.palavra.values.tolist()))
# Out:
# gente

# %% [markdown]
# # Scraping

# %%
import pandas as pd
import numpy as np
import requests

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.edge.service import Service
#com a mudança pro selenium 4.0, algumas coisas mudaram ao inicializar, por exemplo o uso do Service


from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
# %%time

#from selenium import webdriver
service = Service(executable_path = './edg_drv/msedgedriver.exe')
driver = webdriver.Edge(service=service)
#driver.implicitly_wait(50) #fazendo esperar o carregamento das coisas que nunca estão disponiveis imediatamente
urlpage = 'https://term.ooo/'
response = driver.get(urlpage)
driver.implicitly_wait(5)


#driver.find_element_by_xpath('//*[@id="__layout"]/div/nav/div[3]/a[1]/span/span')
# Out:
# Wall time: 3.31 s

# %%
#driver.find_element_by_link_text('TERMO')
service = Service(executable_path = './edg_drv/msedgedriver.exe')
driver = webdriver.Edge(service=service)
#driver.implicitly_wait(50) #fazendo esperar o carregamento das coisas que nunca estão disponiveis imediatamente
urlpage = 'https://term.ooo/'
response = driver.get(urlpage)
driver.implicitly_wait(5)

x_path = '/html/body/wc-modal'
ajuda_sempre_aberta = driver.find_element('xpath',x_path)
ajuda_sempre_aberta.click()

# %%
x_path = '/html/body/wc-modal'
ajuda_sempre_aberta = driver.find_element('xpath',x_path)
ajuda_sempre_aberta.click()

# %%
# enviando a primeira palavra
palavra_sorteada = 'apoie'

x_path_board = '/html/body'
first_word = driver.find_element('xpath',x_path_board)
for letra in palavra_sorteada:
    first_word.send_keys(letra)
    driver.implicitly_wait(0.5)
    
first_word.send_keys(Keys.ENTER)

# %%
# primeira tentativa


x_path_posicao_1 = '//*[@id="hold"]/wc-row[1]//div[1]' #da pracriar um for que pega tudo
x_path_posicao_1 = '/html/body/main/wc-board'

posicao_1 = driver.find_element_by_xpath(x_path_posicao_1)
print(posicao_1.get_attribute('class'))

# %%
from selenium.webdriver.common.action_chains import ActionChains

# %%
elemento = '[id="board0"]'
elemento_interno = '[id="hold"]' #esse é meu segundo shadow_root do site
shadow = driver.find_element(By.CSS_SELECTOR, elemento).shadow_root
inner_shadow = shadow.find_element(By.CSS_SELECTOR, elemento_interno)

print(inner_shadow.text)

# x_path_posicao_1 = '//*[@id="hold"]/wc-row[1]//div[1]'
# shadow.find_element('xpath', x_path_posicao_1)
# Out:
# A
# P
# O
# I
# E

# %%
inner_shadow.get_attribute('class')
# Out:
# ''

# %%
primeira_linha = '[aria-label="palavra 0"]'
inner_shadow_2 = shadow.find_element(By.CSS_SELECTOR, primeira_linha).shadow_root

primeira_letra = '[class="letter wrong"]'
teste = inner_shadow_2.find_element(By.CSS_SELECTOR, primeira_letra)

print(teste.text)
# Out:
# A

# %%
variavel = 1

primeira_letra = f'[termo-pos="{variavel}"]'
teste = inner_shadow_2.find_element(By.CSS_SELECTOR, primeira_letra)


print(teste.text)
# Out:
# P

# %%
teste.get_attribute('class')
# Out:
# 'letter wrong'

# %%
for variavel in range(5):
    print(variavel)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#primeira tentativa



elemento_do_board = '[id="board0"]'

shadow = driver.find_element(By.CSS_SELECTOR, elemento_do_board).shadow_root


#para outras palavras, copiar o codigo abaixo:

lista_da_palavra = []
variavel_primeira_palavra = 0
elemento_primeira_linha_interno_para_shadow = f'[aria-label="palavra {elemento_primeira_linha_interno_para_shadow}"]'
inner_shadow = shadow.find_element(By.CSS_SELECTOR, primeira_linha).shadow_root


for variavel in range(5):
    elemento_primeira_letra = f'[termo-pos="{variavel}"]'
    elemento_html = inner_shadow_2.find_element(By.CSS_SELECTOR, elemento_primeira_letra)
    lista_da_palavra.append(elemento_html.get_attribute('class'))
    
    
lista_da_palavra
# Out:
# ['letter wrong',
#  'letter wrong',
#  'letter wrong',
#  'letter wrong',
#  'letter right']

# %%
dicionario_lista_da_palavra = dict(zip(range(len(lista_da_palavra)), lista_da_palavra))

# %%
print(dicionario_lista_da_palavra)
# Out:
# {0: 'letter wrong', 1: 'letter wrong', 2: 'letter wrong', 3: 'letter wrong', 4: 'letter right'}

# %%
palavra_sorteada = segunda_tentativa

x_path_board = '/html/body'
first_word = driver.find_element('xpath',x_path_board)
for letra in palavra_sorteada:
    first_word.send_keys(letra)
    driver.implicitly_wait(0.5)
    
first_word.send_keys(Keys.ENTER)

# %%
lista_da_palavra_2 = []

variavel_primeira_palavra = 1 #mudar pra variavel no começo da função
elemento_primeira_linha_interno_para_shadow = f'[aria-label="palavra {variavel_primeira_palavra}"]'
inner_shadow = shadow.find_element(By.CSS_SELECTOR, elemento_primeira_linha_interno_para_shadow).shadow_root


for variavel in range(5):
    elemento_primeira_letra = f'[termo-pos="{str(variavel)}"]'
    elemento_html = inner_shadow.find_element(By.CSS_SELECTOR, elemento_primeira_letra)
    lista_da_palavra_2.append([elemento_html.get_attribute('class'), elemento_html.text])
    
    
dicionario_lista_da_palavra_2 = dict(zip(range(len(lista_da_palavra_2)), lista_da_palavra_2))

# %%
dicionario_lista_da_palavra_2
# Out:
# {0: ['letter wrong', 'S'],
#  1: ['letter wrong', 'A'],
#  2: ['letter place', 'G'],
#  3: ['letter wrong', 'R'],
#  4: ['letter right', 'E']}

# %%
elemento_primeira_letra = f'[termo-pos="{str(2)}"]'
elemento_html = inner_shadow_2.find_element(By.CSS_SELECTOR, elemento_primeira_letra)

# %%
elemento_html.get_attribute('class')
# Out:
# 'letter wrong'

# %%
primeira_linha = '[aria-label="palavra 2"]'
inner_shadow_2 = shadow.find_element(By.CSS_SELECTOR, primeira_linha).shadow_root
inner_shadow_2
# Out:
# <selenium.webdriver.remote.shadowroot.ShadowRoot (session="22f9bbb7f0c09007b5f4e883b0e3f4b8", element="65153E0CBAA0BAA81EFF58C4457F9D80_element_302")>

# %%
palavra_sorteada = terceira_tentativa

x_path_board = '/html/body'
first_word = driver.find_element('xpath',x_path_board)
for letra in palavra_sorteada:
    first_word.send_keys(letra)
    driver.implicitly_wait(0.5)
    
first_word.send_keys(Keys.ENTER)

# %%
lista_da_palavra_3 = []

variavel_primeira_palavra = 2 #mudar pra variavel no começo da função
elemento_primeira_linha_interno_para_shadow = f'[aria-label="palavra {variavel_primeira_palavra}"]'
inner_shadow = shadow.find_element(By.CSS_SELECTOR, elemento_primeira_linha_interno_para_shadow).shadow_root


for variavel in range(5):
    elemento_primeira_letra = f'[termo-pos="{str(variavel)}"]'
    elemento_html = inner_shadow.find_element(By.CSS_SELECTOR, elemento_primeira_letra)
    lista_da_palavra_3.append([elemento_html.get_attribute('class'), elemento_html.text])
    
    
dicionario_lista_da_palavra_3 = dict(zip(range(len(lista_da_palavra_3)), lista_da_palavra_3))

# %%
dicionario_lista_da_palavra_3
# Out:
# {0: ['letter place', 'E'],
#  1: ['letter wrong', 'L'],
#  2: ['letter wrong', 'E'],
#  3: ['letter place', 'G'],
#  4: ['letter right', 'E']}

# %%
palavra_sorteada = sorteia_palavra(teste_3.palavra.values.tolist())

x_path_board = '/html/body'
first_word = driver.find_element('xpath',x_path_board)
for letra in palavra_sorteada:
    first_word.send_keys(letra)
    driver.implicitly_wait(0.5)
    
first_word.send_keys(Keys.ENTER)

# %%
#testar se achar, se não continuar no programa

vencedor = 'wc-notify'
notificacao = driver.find_element(By.CSS_SELECTOR, vencedor)

# %%
notificacao.text
# Out:
# ''

# %%
def get_notificacao():
    vencedor = 'wc-notify'
    notificacao = driver.find_element(By.CSS_SELECTOR, vencedor)
    notificacao = notificacao.text
    
    if notificacao == '':
        return True
    else:
        return False

# %%
get_notificacao()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-60-db4eca80eab7> in <module>
# ----> 1 get_notificacao()
#
# <ipython-input-58-501a0934d7e8> in get_notificacao()
#       1 def get_notificacao():
#       2     vencedor = 'wc-notify'
# ----> 3     notificacao = driver.find_element(By.CSS_SELECTOR, vencedor)
#       4     notificacao = notificacao.text
#       5
#
# ~\anaconda3\envs\dh\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     737             value = f'[name="{value}"]'
#     738
# --> 739         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     740
#     741     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\envs\dh\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     343         response = self.command_executor.execute(driver_command, params)
#     344         if response:
# --> 345             self.error_handler.check_response(response)
#     346             response["value"] = self._unwrap_value(response.get("value", None))
#     347             return response
#
# ~\anaconda3\envs\dh\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: MicrosoftEdge=115.0.1901.188)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF720585432+69586]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF720515672+760242]
# 	(No symbol) [0x00007FF7202CB8CC]
# 	(No symbol) [0x00007FF7202A294E]
# 	(No symbol) [0x00007FF720336D0D]
# 	(No symbol) [0x00007FF72034BB78]
# 	(No symbol) [0x00007FF720332B83]
# 	(No symbol) [0x00007FF72030589E]
# 	(No symbol) [0x00007FF720304B6B]
# 	(No symbol) [0x00007FF720306024]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF72075D239+1294553]
# 	(No symbol) [0x00007FF7203849F4]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF720463DF1+33073]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF72045C409+1865]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF72075BE11+1289393]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF72051DC78+20184]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF72051A304+5476]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF72051A3FC+5724]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF72050ECB1+733169]
# 	BaseThreadInitThunk [0x00007FFEE3387614+20]
# 	RtlUserThreadStart [0x00007FFEE3CC26A1+33]

# %% [markdown]
# # Organizando todas as funções!

# %% [markdown]
# - Carregar o DF
# - listar as palavras melhroes rankeadas para começar o jogo
# - iniciar o jogo
# - escolher uma palavra da lista de mais rankeadas
# - mandar a primeira palavra para o jogo
# - retornar dicionario de resultado da primeira palavra

# %% [markdown]
# ## Core Functions - Analitics

# %%
import pandas as pd

def carrega_dataframe_csv(caminho):
    return pd.read_csv(caminho)

# %%
caminho = 'br-utf8.csv'
df = carrega_dataframe_csv(caminho)
df
# Out:
#      palavra  n_vogais  vogais_unicas letra_0 letra_1 letra_2 letra_3 letra_4
# 0      aarao         4              2       a       a       r       a       o
# 1      abner         2              2       a       b       n       e       r
# 2      acaia         4              2       a       c       a       i       a
# 3      acker         2              2       a       c       k       e       r
# 4      aires         3              3       a       i       r       e       s
# ...      ...       ...            ...     ...     ...     ...     ...     ...
# 5420   unica         3              3       u       n       i       c       a
# 5421   unico         3              3       u       n       i       c       o
# 5422   urico         3              3       u       r       i       c       o
# 5423   uteis         3              3       u       t       e       i       s
# 5424   utero         3              3       u       t       e       r       o
#
# [5425 rows x 8 columns]

# %%
import random

def sorteia_palavra(lista_palavra):
    if len(lista_palavra) == 1:
        return lista_palavra[0]
    else:
        return lista_palavra[random.randint(0,(len(lista_palavra)-1))]

# %%
sorteia_palavra(df.palavra)
# Out:
# 'bobea'

# %%
#recebe lista de letra e posicao correta
#lista_exemplo = ['letra',posicao]

def letra_na_posicao(lista_letra_correta, df):
    
    if len(lista_letra_correta) == 0:
        return df
    else:
        for letra, posicao in lista_letra_correta:
            if posicao == 0:
                mask = df.letra_0 == letra
                df = df.loc[mask,:]
            elif posicao == 1:
                mask = df.letra_1 == letra
                df = df.loc[mask,:]
            elif posicao == 2:
                mask = df.letra_2 == letra
                df = df.loc[mask,:]
            elif posicao == 3:
                mask = df.letra_3 == letra
                df = df.loc[mask,:]
            elif posicao == 4:
                mask = df.letra_4 == letra
                df = df.loc[mask,:]

    return df

# %%
letra_certa =[]
teste = letra_na_posicao(letra_certa, df)
teste
# Out:
#      palavra  n_vogais  vogais_unicas letra_0 letra_1 letra_2 letra_3 letra_4
# 0      aarao         4              2       a       a       r       a       o
# 1      abner         2              2       a       b       n       e       r
# 2      acaia         4              2       a       c       a       i       a
# 3      acker         2              2       a       c       k       e       r
# 4      aires         3              3       a       i       r       e       s
# ...      ...       ...            ...     ...     ...     ...     ...     ...
# 6019   unica         3              3       u       n       i       c       a
# 6020   unico         3              3       u       n       i       c       o
# 6021   urico         3              3       u       r       i       c       o
# 6022   uteis         3              3       u       t       e       i       s
# 6023   utero         3              3       u       t       e       r       o
#
# [5425 rows x 8 columns]

# %%
#lista_de_letras_com_posicao = [['g',2]] --- exemplo
#provavelmente será necessário criar uma função que descompacte o dicionario que retorna do site em uma lista com listas

def palavras_com_letra_posicao_errada(lista_de_letras_com_posicao, df):   
    lista = []
    for indice1,indice2 in lista_de_letras_com_posicao:
        lista.append(indice1)
        
        condicao = indice2
        if condicao == 0:
            mask = df.letra_1.isin(lista) | df.letra_2.isin(lista) | df.letra_3.isin(lista) | df.letra_4.isin(lista)
            df = df.loc[mask,:]
        elif condicao == 1:
            mask = df.letra_0.isin(lista) | df.letra_2.isin(lista) | df.letra_3.isin(lista) | df.letra_4.isin(lista) 
            df = df.loc[mask,:]
        elif condicao == 2:
            mask = df.letra_0.isin(lista) | df.letra_1.isin(lista) | df.letra_3.isin(lista) | df.letra_4.isin(lista)
            df = df.loc[mask,:]
        elif condicao == 3:
            mask = df.letra_0.isin(lista) | df.letra_1.isin(lista) | df.letra_2.isin(lista) | df.letra_4.isin(lista)
            df = df.loc[mask,:]
        elif condicao == 4:
            mask = df.letra_0.isin(lista) | df.letra_1.isin(lista) | df.letra_2.isin(lista) | df.letra_3.isin(lista)
            df = df.loc[mask,:]

    return df

# %%
def letras_nao_aceitas(letras, df):
    lista = []
    
    if len(letras) > 1:
        for i in letras:
            lista.append(i)
        mask = ~df.letra_0.isin(lista) & ~df.letra_1.isin(lista) & ~df.letra_2.isin(lista) & ~df.letra_3.isin(lista) & ~df.letra_4.isin(lista)
    else:
        mask = (df.letra_0 != letras) & (df.letra_1 != letras) & (df.letra_2 != letras) & (df.letra_3 != letras) & (df.letra_4 != letras)

    return df.loc[mask,:]

# %% [markdown]
# ## Scraping functions

# %%
import pandas as pd
import numpy as np
import requests

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.edge.service import Service
#com a mudança pro selenium 4.0, algumas coisas mudaram ao inicializar, por exemplo o uso do Service


from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
#inicializand o site
def inicializa_termo():
    service = Service(executable_path = './edg_drv/msedgedriver.exe') #mudança do selenium 4.0
    driver = webdriver.Edge(service=service)

    urlpage = 'https://term.ooo/'
    response = driver.get(urlpage)
    driver.implicitly_wait(5)

    x_path = '/html/body/wc-modal'
    ajuda_sempre_aberta = driver.find_element('xpath',x_path)
    ajuda_sempre_aberta.click()
    driver.implicitly_wait(2)
    return driver

# %%
driver = inicializa_termo()

# %%
#envia palavra

def envia_palavra(palavra_sorteada):
    x_path_board = '/html/body'
    board_inicial = driver.find_element('xpath',x_path_board)
    for letra in palavra_sorteada:
        board_inicial.send_keys(letra)
        driver.implicitly_wait(0.5)#testar, se não funcionar voltar para -> driver.implicitly_wait(0.5)

    board_inicial.send_keys(Keys.ENTER)
    print('palavra-enviada')#apenas pra finalidades de teste, retirar depois

# %%
envia_palavra('apoie')
# Out:
# palavra-enviada

# %%
#retorna dicionario da tentiva de palavra enviada
elemento_do_board = '[id="board0"]'

shadow = driver.find_element(By.CSS_SELECTOR, elemento_do_board).shadow_root

#ainda pensando se vale a pena colocar como variavel global mesmo ou deixar dentro da função

def retorna_dicionario_respostas(variavel): #variavel = numero da tentativa

    
    lista_da_palavra = [] #inicializa a lista
    elemento_primeira_linha_interno_para_shadow = f'[aria-label="palavra {variavel}"]'
    inner_shadow = shadow.find_element(By.CSS_SELECTOR, elemento_primeira_linha_interno_para_shadow).shadow_root


    for variavel in range(5):
        elemento_primeira_letra = f'[termo-pos="{str(variavel)}"]'
        elemento_html = inner_shadow.find_element(By.CSS_SELECTOR, elemento_primeira_letra)
        lista_da_palavra.append([elemento_html.get_attribute('class'), elemento_html.text.lower()])


    return dict(zip(range(len(lista_da_palavra)), lista_da_palavra))

# %%
tentativa = 0
primeira_palavra_respostas = retorna_dicionario_respostas(tentativa)
primeira_palavra_respostas
# Out:
# {0: ['letter wrong', 'a'],
#  1: ['letter place', 'p'],
#  2: ['letter place', 'o'],
#  3: ['letter wrong', 'i'],
#  4: ['letter wrong', 'e']}

# %%
def retorna_resultado_tentativa_palavra(dicionario):

    letras_erradas = ''
    letras_lugar_errado = []
    letras_corretas = []

    for item in dicionario:

        if dicionario[item][0] == 'letter wrong':
            letras_erradas += str(dicionario[item][1])
        elif dicionario[item][0] == 'letter place':
            letras_lugar_errado.append([dicionario[item][1], item])
        elif dicionario[item][0] == 'letter right':
            letras_corretas.append([dicionario[item][1], item])
            
    return letras_erradas, letras_lugar_errado, letras_corretas

# %%
dicionario = primeira_palavra_respostas
letras_erradas, letras_lugar_errado, letras_corretas = retorna_resultado_tentativa_palavra(dicionario)

# %%
print(letras_erradas)
print(letras_lugar_errado)
print(letras_corretas)
# Out:
# aie
# [['p', 1], ['o', 2]]
# []

# %%
#função que vai dizer se ta funcionando ou não

def get_notificacao():
    vencedor = 'wc-notify'
    notificacao = driver.find_element(By.CSS_SELECTOR, vencedor)
    notificacao = notificacao.text
    
    if notificacao == '':
        return True
    else:
        return False

# %%
melhores_palavras_para_vogais = df[df.vogais_unicas == 4]
melhores_palavras_para_vogais
# Out:
#      palavra  n_vogais  vogais_unicas letra_0 letra_1 letra_2 letra_3 letra_4
# 15     aecio         4              4       a       e       c       i       o
# 114    uniao         4              4       u       n       i       a       o
# 196    acuei         4              4       a       c       u       e       i
# 219    adiou         4              4       a       d       i       o       u
# 276    afiou         4              4       a       f       i       o       u
# 322    aguei         4              4       a       g       u       e       i
# 366    aliou         4              4       a       l       i       o       u
# 505    apeio         4              4       a       p       e       i       o
# 514    apeou         4              4       a       p       e       o       u
# 529    apoie         4              4       a       p       o       i       e
# 641    ateio         4              4       a       t       e       i       o
# 644    ateou         4              4       a       t       e       o       u
# 679    atuei         4              4       a       t       u       e       i
# 703    aveio         4              4       a       v       e       i       o
# 714    aviou         4              4       a       v       i       o       u
# 1076   caiou         4              4       c       a       i       o       u
# 1893   ecoai         4              4       e       c       o       a       i
# 3312   meiao         4              4       m       e       i       a       o
# 3715   odeia         4              4       o       d       e       i       a
# 3813   ousai         4              4       o       u       s       a       i
# 3817   ousei         4              4       o       u       s       e       i
# 3825   ouvia         4              4       o       u       v       i       a
# 4328   raiou         4              4       r       a       i       o       u
# 5547   ureia         4              4       u       r       e       i       a
# 5587   vaiou         4              4       v       a       i       o       u
# 5963   aureo         4              4       a       u       r       e       o

# %%
sorteia_palavra(melhores_palavras_para_vogais.palavra.values.tolist())
# Out:
# 'ousai'

# %%
def first_attempt(df):
    melhores_palavras_para_vogais = df[df.vogais_unicas == 4]
    return sorteia_palavra(melhores_palavras_para_vogais.palavra.values.tolist())

# %%
first_attempt(df)
# Out:
# 'ateio'

# %% [markdown]
# # teste de inicialização e resolução

# %%
caminho = 'br-utf8.csv'
df = carrega_dataframe_csv(caminho)

driver = inicializa_termo()

terminou = get_notificacao()

while terminou == False:
    for tentativa in range(5):
        
        if tentativa == 0:
            palavra_sorteada = first_attempt(df)
            
        
            
    
    
    
    
    terminou = get_notificacao()
    break
